# %% [markdown]
# # Анализ вакансии для аналитиков данных на Linkedin

# %% [markdown]
# **Цель:** Визуализировать информацию о рынке вакансий для аналитиков в Европе
#
# **Источник данных:** информация с сайта linkedin.com. Данные извлечены из html-кодов страниц 23 мая 2023 г.

# %% [markdown]
# ## Представление обработанных данных в Tableau

# %% [markdown]
# ссылка на Tableau: https://public.tableau.com/app/profile/liudmila2867/viz/DADS/Dashboard2?publish=yes

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Начнем с того, что ознакомимся с данными перед обработкой (загрузим данные, выведем датасет для ознакомления, определим типы данных, пропущенные значения и дубликаты)

# %%
# импортируем необходимые библиотеки

import pandas as pd

# %%
# загрузим датасет
data = pd.read_csv('D:\linkedin.csv')

# %%
# изучим датасет

df = data.copy()
df.head(15)
# Out:
#                               title       location          country  \
# 0                      Data Analyst          Basel      Switzerland
# 1          Data Analyst - Logistics       Coventry   United Kingdom
# 2          Data Analyst - Logistics       Coventry   United Kingdom
# 3   Data Analyst (Space & Planning)   South Molton   United Kingdom
# 4                      Data Analyst         Lugano      Switzerland
# 5          Data Analyst - Logistics    Southampton   United Kingdom
# 6                      Data Analyst          Leeds   United Kingdom
# 7                      Data Analyst       Nuneaton   United Kingdom
# 8                      Data Analyst          Paris           France
# 9     Data Analyst - Hybrid Working      Cambridge   United Kingdom
# 10                     Data Analyst  West Midlands   United Kingdom
# 11          Commercial Data Analyst       Schiphol      Netherlands
# 12               Asset Data Analyst        Chester   United Kingdom
# 13            Data Analyst - Hybrid      Cambridge   United Kingdom
# 14                     Data Analyst    Craven Arms   United Kingdom
#
#    employment_type                                       company_name  \
# 0          On-site           PharmiWeb.Jobs: Global Life Science Jobs
# 1          On-site                               Resolute Recruitment
# 2          On-site                               Resolute Recruitment
# 3          On-site                                Mole Valley Farmers
# 4          On-site                                            FORFIRM
# 5          On-site                               Butler, Bridge & May
# 6          On-site                     Maria Mallaband Care Group Ltd
# 7           Hybrid                                        Kelly Group
# 8          On-site                                              eXalt
# 9          On-site                                         Blue Arrow
# 10         On-site                                     Mexa Solutions
# 11         On-site                               Royal Schiphol Group
# 12         On-site  networx | Recruitment Software & Services by IRIS
# 13         On-site                                         Blue Arrow
# 14   not specified  networx | Recruitment Software & Services by IRIS
#
#              employee_qty                  company_field  \
# 0         11-50 employees        Staffing and Recruiting
# 1           not specified                  not specified
# 2           not specified                  not specified
# 3           not specified                  not specified
# 4           not specified                  not specified
# 5           not specified                  not specified
# 6           not specified                  not specified
# 7           not specified                  not specified
# 8     501-1,000 employees  IT Services and IT Consulting
# 9           not specified                  not specified
# 10          not specified                  not specified
# 11  1,001-5,000 employees          Airlines and Aviation
# 12          not specified                  not specified
# 13          not specified                  not specified
# 14          not specified                  not specified
#
#                                                skills  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   <span class="visually-hidden"><!-- -->Skills: ...
# 9                                                None
# 10                                               None
# 11  <span class="visually-hidden"><!-- -->Skills: ...
# 12                                               None
# 13                                               None
# 14                                               None
#
#                                       job_description  applicants
# 0                               What You Will Achi...        47.0
# 1                                                             NaN
# 2                                Data Analyst - Lo...         NaN
# 3                                 Salary:     To b...         NaN
# 4                                 FORFIRM     is p...         NaN
# 5                                Location: Southam...         NaN
# 6                                We’re Maria Malla...         NaN
# 7                                Kelly Group are s...         NaN
# 8                                Qui sont-ils ?   ...       140.0
# 9                                 Data Analyst    ...         NaN
# 10                                Hybrid - West Mi...         NaN
# 11                              De functie    Welk...        13.0
# 12                               Do you have the d...         NaN
# 13                                Data Analyst    ...         NaN
# 14                               Are you passionat...         NaN

# %%
# изучим пропуски и типы данных 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            998 non-null    object
#  1   location         998 non-null    object
#  2   country          998 non-null    object
#  3   employment_type  998 non-null    object
#  4   company_name     996 non-null    object
#  5   employee_qty     998 non-null    object
#  6   company_field    998 non-null    object
#  7   skills           998 non-null    object
#  8   job_description  998 non-null    object
#  9   applicants       838 non-null    float64
# dtypes: float64(1), object(9)
# memory usage: 78.1+ KB

# %%
# найдем пропущенные значения в датасете

df.isnull().sum().sort_values(ascending=False)
# Out:
# applicants         160
# company_name         2
# title                0
# location             0
# country              0
# employment_type      0
# employee_qty         0
# company_field        0
# skills               0
# job_description      0
# dtype: int64

# %% [markdown]
# Имеет смысл также выявить неявные пропуски в столбцах ('None','0','not specified')

# %%
# изменим тип данных в столбце applicants на стороковый для возможности выполнения следующего цикла

df['applicants'] = df['applicants'].astype('str')

# %%
# проверяем каждый столбец на наличие неявных пропусов

for i in df.columns:
    #del df['job_description']
    print('Столбец:',i)
    print('Количество уникальных неявных пропущенных значений в столбце:',df[df[i].str.contains('None')|df[i].str.contains(' 0 ')|\
    df[i].str.contains('not specified')][i].nunique())
    print(df[df[i].str.contains('None')|df[i].str.contains(' 0 ')|\
    df[i].str.contains('not specified')][i].unique())
    continue
# Out:
# Столбец: title
# Количество уникальных неявных пропущенных значений в столбце: 0
# []
# Столбец: location
# Количество уникальных неявных пропущенных значений в столбце: 0
# []
# Столбец: country
# Количество уникальных неявных пропущенных значений в столбце: 0
# []
# Столбец: employment_type
# Количество уникальных неявных пропущенных значений в столбце: 1
# ['not specified']
# Столбец: company_name
# Количество уникальных неявных пропущенных значений в столбце: 0
# []
# Столбец: employee_qty
# Количество уникальных неявных пропущенных значений в столбце: 1
# ['not specified']
# Столбец: company_field
# Количество уникальных неявных пропущенных значений в столбце: 1
# ['not specified']
# Столбец: skills
# Количество уникальных неявных пропущенных значений в столбце: 1
# ['None']
# Столбец: job_description
# Количество уникальных неявных пропущенных значений в столбце: 11
# ["                            bloomon is turning the flower industry on its head – for the better. How? By disrupting the traditional supply chain, where most florists operate offline and have done for decades. bloomon creates seasonal collections using unusual stems to deliver unique flower arrangements on repeat or as a unique gift. We always use field-fresh high-quality flowers straight from the grower and deliver them to our customers through a high-tech and highly creative platform.   We launched in Amsterdam in 2014 and went from start-up to scale-up at hypersonic speed. In 2021 we joined forces with Bloom &amp; Wild, the UK's fastest-growing e-commerce company (according to the Financial Times). Driven by our vision of creating the destination for making life a little more thoughtful and beautiful, we're now part of Europe's leading online flower company.   Our group is backed by top-tier investors including General Catalyst (backers of Airbnb and Deliveroo), who led our £75 million Series D funding round in January 2021, alongside Index Ventures (investors in Wise and Glossier). We are home to a family of 3 strong brands, Bloom &amp; Wild, bloomon, and Bergamotte. Together, we are active in 8 countries.   We really care about creating a diverse and inclusive team and we welcome people from all backgrounds, with different perspectives, ideas and experiences to work with us. In our team, everyone has the freedom to give their opinion, grow in their career and be part of a genuinely caring and inclusive team.    The team    We’re on a mission to make data at the heart of what we do as at Bloom &amp; Wild. You’ll work closely with the Operations team to drive data driven decision making within all areas of Operations. You’ll be joining the Analytics &amp; BI team and there will also be the opportunity to work with and learn from the rest of the team.    The role    We’re looking for an Operations Analyst to join our team. Reporting to the area lead of the BI Operations team as they optimise getting our products from farm to recipient in the most efficient way possible. This newly created role has lots of potential for future growth.    Please note that only applicants with intermediate- advanced hands-on SQL experience will be considered. This will be tested during the application process.       You'll have ownership of Operations Squad’s analytical roadmap (with support as needed) and be responsible for sizing and prioritising work to deliver the most impactful and timely insights.   You will work with several key parts of the Operations team these include:   Fulfillment &amp; Delivery - working closely with the team to ensure that we effectively track fulfillment and carrier partner performance that optimises customer satisfaction and profitability.   Trading team - working closely with this team to ensure the optimal amount of stock to sell and avoid any wastage.   Sustainability - we are actively working to be a net 0 emissions company. You’ll be working with our sustainability team in order to understand the data needs, and challenges as well as focus on the key areas of impact.   Own fulfilment team - we have different warehouses in different countries. You will help provide this team with reporting to help optimise customer satisfaction.   Supply Chain and Quality - You will help this team to measure the quality of products including non floral gifts. You will create reporting to ensure that we achieve a high customer NPS and provide recommendations if you identify any areas for improvement.   Customer delight- You will support the customer delight team to understand the performance of our help centre, providing recommendations on areas we could look to improve.   This role will be a combination of building reporting and investigative analysis. You will be able to navigate the opportunities/challenges of both.   You are focused on the most valuable and high impact work and are not afraid to push back on requests if  ...
#  "                            Bloom &amp; Wild is re-inventing the $60B global flower industry. Over a billion flower exchanges take place every year and industry satisfaction levels are low. Driven by our vision of creating the destination for making life a little more thoughtful and beautiful, we do things differently. From inventing letterbox flowers to founding The Thoughtful Marketing Movement. And we’ve seen impressive traction to date - we are Europe’s largest direct to consumer flower company.   In January 2021 we announced our £75 million Series D funding round, led by General Catalyst (backers of Airbnb and Deliveroo), alongside other top tier investors including Index Ventures (investors in Wise and Glossier). We are home to a family of 3 strong brands, Bloom &amp; Wild, bloomon and Bergamotte, having acquired bloomon in April 2021 and Bergamotte in July 2021. Together, we are active in 8 countries.   We really care about creating a diverse and inclusive team and we welcome people from all backgrounds, with different perspectives, ideas and experiences to work with us. In our team, everyone has the freedom to give their opinion, grow in their career and be part of a genuinely caring and inclusive team.    The team    We’re on a mission to make data at the heart of what we do as at Bloom &amp; Wild. You’ll work closely with the Operations team to drive data-driven decision-making within all areas of Operations. You’ll be joining the Analytics &amp; BI team and there will also be the opportunity to work with and learn from the rest of the team.    The role    We’re looking for an Operations Analyst to join our team. Reporting to the area lead of the BI Operations team as they optimise getting our products from farm to recipient in the most efficient way possible. This newly created role has lots of potential for future growth.    Please note that only applicants with intermediate- advanced hands-on SQL experience will be considered. This will be tested during the application process.       You'll have ownership of Operations Squad’s analytical roadmap (with support as needed) and be responsible for sizing and prioritising work to deliver the most impactful and timely insights.   You will work with several key parts of the Operations team these include:   Fulfillment &amp; Delivery - working closely with the team to ensure that we effectively track fulfillment and carrier partner performance that optimises customer satisfaction and profitability.   Trading team - working closely with this team to ensure the optimal amount of stock to sell and avoid any wastage.   Sustainability - we are actively working to be a net 0 emissions company. You’ll be working with our sustainability team in order to understand the data needs, and challenges as well as focus on the key areas of impact.   Own fulfilment team - we have different warehouses in different countries. You will help provide this team with reporting to help optimise customer satisfaction.   Supply Chain and Quality - You will help this team to measure the quality of products including non floral gifts. You will create reporting to ensure that we achieve a high customer NPS and provide recommendations if you identify any areas for improvement.   Customer delight- You will support the customer delight team to understand the performance of our help centre, providing recommendations on areas we could look to improve.   This role will be a combination of building reporting and investigative analysis. You will be able to navigate the opportunities/challenges of both.   You are focused on the most valuable and high impact work and are not afraid to push back on requests if they do not have a clear impact/use.   This role is fast paced, so it will be important that you'll be able to identify quick wins and make trade-offs while maintaining analytical best practice.   You'll provide robust and easy to understand recommendations from your analysis that can be explained to techn ...
#  '                             What We Offer\u202f      Enjoy a high level of responsibility and immediate client interactions under the guidance of senior team members.  Help our clients to target, measure, and improve mission-critical business metrics and generate a demonstrable return on investment.  Working with other Senior Data Scientists to take data throughout its lifecycle - acquisition, exploration, data cleaning, integration, analysis, interpretation, and visualization.  Become part of a fast-growing international and diverse team.      Who We Are    We are Metyis. We are a dynamic and forward-thinking consultancy firm that operates across a wide range of industries, creating solutions that are tailored to specific needs. We bring long-lasting impact and growth to our partners and clients.   With our multidisciplinary teams we create bold strategies and innovative solutions that are tailored to our client’s needs and help them capitalizing opportunities. Together we strive to bring long-lasting impact and celebrate collective victories.   At Metyis we share an entrepreneurial mindset, a compelling passion to create, and, more importantly, a firm belief in our partnership-driven business model. This is embedded in our culture and safeguarded as we evolve. Our team counts over 450 ambitious professionals with various backgrounds, spread over several continents. Our work environment unifies creative problem-solving and strategic thinking. We provide resources to visionaries who understand the direction that the world is moving. Tomorrow’s world is data-driven. It is digital. It is international.   Become part of the journey, become part of Metyis. Partners for impact.    What You Will Do\u202f      Performing data analysis in the field of Marketing Analytics, CLM/CRM analytics, and/or Risk analytics  Analyses conducted in typical analytical tools ranging from SAS, SPSS, Eviews, R, Python, SQL, Teradata, Hadoop, Access, Excel, etc.  Communicating analyses via compelling presentations  Solving problems, disaggregate issues, develop hypotheses, and develop actionable recommendations from data and analysis  Preparing and facilitating workshops  Managing stakeholders and communicating with executives      What you’ll bring\u202f\u202f      0 - 2 years of professional work experience in the analytics domain  An advanced degree in a quantitative field (e.g. mathematics, computer programming, etc.)  An ability to think analytically, decompose problem sets, develop hypotheses and recommendations from data analysis  Strong technical skills regarding data analysis, statistics, and programming. Strong working knowledge of, Python, Hadoop, SQL, and/or R.  Working knowledge of Python data tools (e.g. Jupyter, Pandas, Scikit-Learn, Matplotlib)  Ability to talk the language of statistics, finance, and economics a plus  Profound knowledge of the English language  Good to have experience in the Retail and/or Banking industry                          '
#  '                            Du liebst Daten? Dann ist es Zeit, uns Dein Profil zu schicken.  Die trans-o-flex Gruppe ist in Europa die erste Wahl für alle Firmen, die eine schnelle, sichere und exzellente Logistik für sensible Güter benötigen. Wir bieten eine breite Palette an Dienstleistungen: europaweiter Transport von Paketen und Paletten in einem Netzwerk, Transporte mit aktiver Temperaturführung im Bereich von 2 °C bis 8 °C oder 15 °C bis 25 °C, Lagerung, Kommissionierung, Pick &amp; Pack oder Mehrwertdienste.  Die intelligente Nutzung von Daten erlaubt es uns echte Mehrwerte zu schaffen. Der gezielte Ausbau unserer Analytics Tätigkeiten ist daher ein zentrales und strategisches Ziel unseres Unternehmens.  Werde Teil unseres neu geschaffenen Data Experience Team,  spüre die Start-Up Mentalität in einem etablierten Unternehmen  und unseren besonderen Teamgeist! Unser Team verwendet datengetriebene Modelle u. a. zur intelligenten Steuerung von Prozessen, Berechnung von optimalen Routen oder zur Optimierung des eingesetzten Fuhrpark. Kurz gesagt: Wir sind Problemlöser.  Aufgabenprofil:  Deine Aufgabe ist der Aufbau und die Weiterentwicklung unseres Data Lakes sowie das Erstellen von Datenlösungen, die den Unterschied machen. Zusammen mit unserem Data Experience Team versorgst Du den Data Lake und unsere Applikationen mit allen relevanten Daten.  Bei uns hast Du die Möglichkeit, verschiedene Unternehmensbereiche mit Deiner Expertise zu bereichern und die Data Analytics Strategie des Unternehmens aktiv mitzugestalten.   Gestaltung, Umsetzung und Weiterentwicklung von Data Analytics Use Cases und Lösungen  Einsatz von aktuellen Advanced Analytics Methoden in einer professionellen Umgebung mit Python/PySpark  Interpretation, Visualisierung und Kommunikation von Ergebnissen/Lösungen an die Fachabteilungen und die IT  Unternehmensweite Zusammenarbeit mit vielen weiteren Abteilungen und in Projekten    Qualifikationsprofil:   Praktischer Bezug zu Data Science, Machine Learning oder Data Analytics, idealerweise durch einen Studienabschluss  Erfahrung in Programmierung (z. B. Python, R, SAS), Datenbankabfragen (z. B. SQL) und Data Science Methoden  Fähigkeit, ökonomische Fragestellungen mit einer wissenschaftlichen, pragmatischen, analytischen Herangehensweise anzugehen und zu lösen  Kreativität und Innovationsfreude verbunden mit hoher Lern-, Veränderungs- und Einsatzbereitschaft  Kommunikationsgeschick und Begeisterung für die Arbeit in einem dynamischen Team    Unsere Benefits:  Wir bieten Dir einen hohen Gestaltungsspielraum, anspruchsvolle Projekte, ein sehr spannendes Umfeld mit netten Kollegen sowie:   Work-Life Balance: 30 Urlaubstage  Flexibility: Flexibles Arbeitszeitmodell sowie die Möglichkeit mobil zu arbeiten  Mobilität: Laptop und Geschäftshandy  Training: Durch unsere trans-o-flex Training und Service GmbH bieten wir regelmäßige Fortbildungs- und Weiterbildungsmöglichkeiten.   Development: Entwicklungschancen in einem dynamisch wachsenden Unternehmen. Wir vertrauen Deinen Fähigkeiten und geben Dir den Raum, eigene Ideen und Lösungen voranzutreiben  Zusatzleistungen: Vermögenswirksame Leistungen sowie betriebliche Altersvorsorge  Knowledge Sharing: Gezieltes Onboarding und intensive Einarbeitung durch eine enge Zusammenarbeit mit Deinen Team-Kollegen  Team Building/Networking: Mittels regelmäßigen Mitarbeiterveranstaltungen, wie Sommerfest, Weihnachtsfeier und weiteren internen Veranstaltungen  Freiwilligentag: Freistellung an bis zu einem Arbeitstag pro Jahr für soziale Tätigkeiten    Neugierig? Wir freuen uns, Dich kennenzulernen.  Bitte sende uns Deine vollständigen Bewerbungsunterlagen (Anschreiben, Lebenslauf, Zeugnisse etc.) unter Angabe deiner Gehaltsvorstellung über unser Onlineportal.  Dein Ansprechpartner steht Dir bei Rückfragen gerne zur Verfügung   Janina Klohr  Recruiterin  + 496201 988 0                          '
#  '                             Für die interne IT-Abteilung unseres Auftraggebers, eine 100% Tochter eines großen Automobilkonzerns, suchen wir einen erfahrenen BI Spezialisten / Architekt als stellvertretender Teamleiter in der Rolle als Inhouse Consultant (m/w/d) der für die Konzeption sowie Mit- und Weiterentwicklung der BI-Applikationen innerhalb der Gesamtstrategie des New MIS Projekt (Management-Informations-Systems) verantwortlich ist.     Wir kennen die Anforderungen unserer Auftraggeber und eröffnen Ihnen passgenaue Karriereperspektiven! Wir analysieren Ihr Profil und coachen Sie objektiv im Bewerbungsprozess.      Stellenbeschreibung:   Zur Verstärkung und Ausbau des internen IT-Bereichs suchen wir Sie, einen erfahrenen BI-Spezialisten der als „Kennzahlen-Junkie“, und mit dem Blick „über den Tellerrand“, für die Data Warehouse-Struktur inkl. der Datenbanken, Datenverarbeitung und Reporting verantwortlich ist. Die aufbereiteten Daten gelten als zentrales Steuerelement für die Steakholder und deren Autohausgesellschaften.     Im Rahmen der digitalen Transformation plant das Unternehmen zukünftig die Migration auf SAP S/4 HANA. Hierbei wird es Ihre Aufgabe sein, die BI-Projekte im zukünftigen SAP System mit aufzubauen und „Alt-Technologien“ wie Cognos Analytics abzulösen und in Technologien wie Microsoft Power BI zu überführen.     Unser Auftraggeber gehört zu einem international führenden Automobilkonzern. Das Unternehmen ist als Dienstleistungsgesellschaft zuständig für die interne Steuerung- und Koordination, u.a. der IT (Retail-Systeme), aller bundesweiten Verkaufs- und Serviceniederlassungen.     Zu Ihren wesentlichen Aufgaben in dieser Position gehören:   Verantwortung für das Data Engineering im zentralen Data Warehouse  Konzeption und (Mit) Entwicklung des New MIS Projekt im Rahmen der Gesamtstrategie  Datenbank-Administration der BI Center sowie Dokumentation der Datenbankstruktur  Betreuung der Reporting-, Planungs- und Analytics-Anwendungen  Ausbau und kontinuierliche Verbesserung der Analytics Landschaft  Berichtsdefinition  Integration, Wartung und Support (2nd und 3rd Level) von Data Warehousing Prozessen und analytischen Applikationen  Dokumentation der Datenbankstruktur      Ihr Profil:   Sie greifen auf Ihre Kenntnisse aus der BI Softwareentwicklung zurück und gestalten auf Basis Ihrer fachlichen Kompetenz das Projektergebnis  Sie bringen sehr gute Kenntnisse im Bereich Enterprise Datenbanken (MS SQL Server, IBM Cognos TM1, ...) mit  Sie haben mehrjährige Kenntnisse in der Datenbankentwicklung (relational und multidimensional)  Sie haben gute Kenntnisse in Business Intelligence- Software wie z.B. Cubeware, MS Analysis Server, IBM TM1, MS Power Apps, MS Power BI)  Außerdem bringen Sie sehr gute Erfahrungen im in Microsoft 365 mit  Darüber hinaus gehören Konzeptentwicklung, -prüfung und -beratung wie z. B.- Analyseworkflows (Ursache -&gt; Wirkung) zu Ihren Erfahrungen  Idealerweise Branchenkenntnis aus und/oder im Umfeld des Automobilhandels       Auftraggeber:   Unser Auftraggeber gehört zu einem international führenden Automobilkonzern und ist als IT Dienstleistungsgesellschaft zuständig für die interne Steuerung- und Koordination, u.a. der IT (Retail-Systeme) aller bundesweiten Verkaufs- und Serviceniederlassungen.  Eine der strategischen IT-Vorhaben ist die Forcierung der Digitalisierung in den Niederlassungen. Hierbei geht es um die Entwicklung und Einführung von innovativen und kundenfokussierten Lösungen für den Automobilhandel.  Als Arbeitgeber bietet unser Auftraggeber den Mitarbeitenden umfassende Benefits und Möglichkeiten der persönlichen Weiterbildung in Form von Personalentwicklungsprogrammen.  Neben einer attraktiven Gehaltsvergütung werden ergänzende Bonusregelungen und Zusatzleistungen wie z. B. Werksangehörigenleasing oder Mitarbeiterrabatte sowie eine betriebliche Altersvorsorge angeboten.  Hybride Arbeitszeitmodelle bieten die Möglichkeit den Arbeitsalltag individuell zu gestalten. Wen ...
#  '                             About Agoda    Agoda is an online travel booking platform for accommodations, flights, and more. We build and deploy cutting-edge technology that connects travelers with more than 2.5 million accommodations globally. Based in Asia and part of Booking Holdings, our 6,000+ employees representing 90+ nationalities foster a work environment rich in diversity, creativity, and collaboration. We innovate through a culture of experimentation and ownership,\u202fenhancing the ability for our customers to experience the world.    Get to know our team:     The Performance Marketing Team of Agoda is a world leader in online marketing. This department is highly data-driven and focused on developing at-scale marketing programs that improve the lifetime value of Agoda customers through measurable marketing programs and channels. The team is a blend of the best analysts, marketing strategists, and data scientists in the world. The marketing leadership at Agoda has deep experience in data science, product, strategy, and other marketing fields and has built an organization that thrives on data, creative ideas, and technology. The Performance Marketing Team also fosters a great learning environment. You will be able to learn and grow by working closely with experts from a variety of backgrounds from all over the world.   Due to continued expansion,  there are multiple analyst roles within the marketing team across different marketing channels. While the scope will vary depending on these channels, here are some examples:       Experimentation and optimizing campaign performance: Experiment with ads/campaign structures and bidding&amp; pricing strategies on partners such as Google, Bing, TripAdvisor, Trivago, and other search engines. Adapt to new product features and roll out changes from successful tests.    Modeling: Analyze vast amounts of data generated by experiments, develop predictive models using data science techniques (e.g. understanding the impact on bookings from large-scale TV campaigns or demand elasticity from pricing optimization), and liaise with product teams on an implementation roadmap    Reporting, analysis, and insights: Building dashboards to track performance, derive insights, understand growth levers, and communicate recommendations via presentations to stakeholders       What you’ll Need to Succeed:        Bachelor’s degree or higher from top university in a quantitative subject e.g. computer science, mathematics, engineering business, science, or relevant field of study    0 to 4 years experience in data crunching from top-tier consulting, investment banking, private equity or strategy/business role for a fast-growing global tech company    Experience in one or more data analysis packages or databases, e.g., SQL, SAS, R, SPSS, Python, VBA and visualization tools, e.g. Tableau, Power BI, etc.    Excellent verbal and written communication skills in English    Ability to move fast and be efficient, making decisions on objective data evidence    Innate desire to take ownership, make an impact and influence outcomes    Excellent organizational skills, attention to detail and ability to work independently       It’s great if you have:        Experience in digital marketing or e-commerce    Experience with A/B testing and other testing metrics    Strong presentation and negotiation skills      #entrylevel #STRA#ANLS#MRKT#3 #sanfrancisco #sanjose #losangeles #sandiego #oakland #denver #miami #orlando #atlanta #chicago #boston #detroit #newyork #portland #philadelphia #dallas #houston #austin #seattle #washdc #tirana #yerevan #sydney #melbourne #perth #vienna #graz #linz #baku #minsk #brussels #antwerp #ghent #charleroi #liege #saopaolo #sofia #toronto #vancouver #montreal #shanghai #beijing #shenzhen #zagreb #cyprus #prague #Brno #Ostrava #copenhagen #cairo #alexandria #giza #estonia #helsinki #paris #nice #marseille #rouen #lyon #toulouse #tbilisi #berlin #munich #hamburg #stuttgart #cologne #fr ...
#  '                             About Agoda    Agoda is an online travel booking platform for accommodations, flights, and more. We build and deploy cutting-edge technology that connects travelers with more than 2.5 million accommodations globally. Based in Asia and part of Booking Holdings, our 6,000+ employees representing 90+ nationalities foster a work environment rich in diversity, creativity, and collaboration. We innovate through a culture of experimentation and ownership,\u202fenhancing the ability for our customers to experience the world.     Get to Know our    Team:     The Performance Marketing Team of Agoda is a world leader in online marketing. This department is highly data-driven and focused on developing at-scale marketing programs that improve the lifetime value of Agoda customers through measurable marketing programs and channels. The team is a blend of the best analysts, marketing strategists, and data scientists in the world. The marketing leadership at Agoda has deep experience in data science, product, strategy, and other marketing fields and has built an organization that thrives on data, creative ideas, and technology. The Performance Marketing Team also fosters a great learning environment. You will be able to learn and grow by working closely with experts from a variety of backgrounds from all over the world.   Due to continued expansion,  there are multiple analyst roles within the marketing team across different marketing channels. While the scope will vary depending on these channels, here are some examples:       Experimentation and optimizing campaign performance: Experiment with ads/campaign structures and bidding&amp; pricing strategies on partners such as Google, Bing, TripAdvisor, Trivago, and other search engines. Adapt to new product features and roll out changes from successful tests.    Modeling: Analyze vast amounts of data generated by experiments, develop predictive models using data science techniques (e.g. understanding the impact on bookings from large-scale TV campaigns or demand elasticity from pricing optimization), and liaise with product teams on an implementation roadmap    Reporting, analysis, and insights: Building dashboards to track performance, derive insights, understand growth levers, and communicate recommendations via presentations to stakeholders        What you’ll Need to    Succeed:        Bachelor’s degree or higher from top university in a quantitative subject e.g. computer science, mathematics, engineering business, science, or relevant field of study    0 to 4 years experience in data crunching from top-tier consulting, investment banking, private equity or strategy/business role for a fast-growing global tech company    Experience in one or more data analysis packages or databases, e.g. SQL, SAS, R, SPSS, Python, VBA and visualization tools, e.g. Tableau, Power BI, etc.    Excellent verbal and written communication skills in English    Ability to move fast and be efficient, making decisions on objective data evidence    Innate desire to take ownership, make an impact and influence outcomes    Excellent organizational skills, attention to detail and ability to work independently        It’s Great if you    Have:        Experience in digital marketing or e-commerce    Experience with A/B testing and other testing metrics    Strong presentation and negotiation skills      #entrylevel #STRA#ANLS#MRKT#3 #sanfrancisco #sanjose #losangeles #sandiego #oakland #denver #miami #orlando #atlanta #chicago #boston #detroit #newyork #portland #philadelphia #dallas #houston #austin #seattle #washdc #tirana #yerevan #sydney #melbourne #perth #vienna #graz #linz #baku #minsk #brussels #antwerp #ghent #charleroi #liege #saopaolo #sofia #toronto #vancouver #montreal #shanghai #beijing #shenzhen #zagreb #cyprus #prague #Brno #Ostrava #copenhagen #cairo #alexandria #giza #estonia #helsinki #paris #nice #marseille #rouen #lyon #toulouse #tbilisi #berlin #munich #hamburg #stuttgart # ...
#  '                             About Agoda    Agoda is an online travel booking platform for accommodations, flights, and more. We build and deploy cutting-edge technology that connects travelers with more than 2.5 million accommodations globally. Based in Asia and part of Booking Holdings, our 6,000+ employees representing 90+ nationalities foster a work environment rich in diversity, creativity, and collaboration. We innovate through a culture of experimentation and ownership,\u202fenhancing the ability for our customers to experience the world.    Get To Know The Team:     The Performance Marketing Team of Agoda is a world leader in online marketing. This department is highly data-driven and focused on developing at-scale marketing programs that improve the lifetime value of Agoda customers through measurable marketing programs and channels. The team is a blend of the best analysts, marketing strategists, and data scientists in the world. The marketing leadership at Agoda has deep experience in data science, product, strategy, and other marketing fields and has built an organization that thrives on data, creative ideas, and technology. The Performance Marketing Team also fosters a great learning environment. You will be able to learn and grow by working closely with experts from a variety of backgrounds from all over the world.   Due to continued expansion,  there are multiple analyst roles within the marketing team across different marketing channels. While the scope will vary depending on these channels, here are some examples:       Experimentation and optimizing campaign performance: Experiment with ads/campaign structures and bidding&amp; pricing strategies on partners such as Google, Bing, TripAdvisor, Trivago, and other search engines. Adapt to new product features and roll out changes from successful tests.    Modeling: Analyze vast amounts of data generated by experiments, develop predictive models using data science techniques (e.g. understanding the impact on bookings from large-scale TV campaigns or demand elasticity from pricing optimization), and liaise with product teams on an implementation roadmap    Reporting, analysis, and insights: Building dashboards to track performance, derive insights, understand growth levers, and communicate recommendations via presentations to stakeholders        What you’ll Need to    Succeed:        Bachelor’s degree or higher from top university in a quantitative subject e.g. computer science, mathematics, engineering business, science, or relevant field of study    0 to 4 years experience in data crunching from top-tier consulting, investment banking, private equity or strategy/business role for a fast-growing global tech company    Experience in one or more data analysis packages or databases, e.g. SQL, SAS, R, SPSS, Python, VBA and visualization tools, e.g. Tableau, Power BI, etc.    Excellent verbal and written communication skills in English    Ability to move fast and be efficient, making decisions on objective data evidence    Innate desire to take ownership, make an impact and influence outcomes    Excellent organizational skills, attention to detail and ability to work independently        It’s Great if you    Have:        Experience in digital marketing or e-commerce    Experience with A/B testing and other testing metrics    Strong presentation and negotiation skills      #STRA#ANLS#MRKT#3 #sanfrancisco #sanjose #losangeles #sandiego #oakland #denver #miami #orlando #atlanta #chicago #boston #detroit #newyork #portland #philadelphia #dallas #houston #austin #seattle #washdc #tirana #yerevan #sydney #melbourne #perth #vienna #graz #linz #baku #minsk #brussels #antwerp #ghent #charleroi #liege #saopaolo #sofia #toronto #vancouver #montreal #shanghai #beijing #shenzhen #zagreb #cyprus #prague #Brno #Ostrava #copenhagen #cairo #alexandria #giza #estonia #helsinki #paris #nice #marseille #rouen #lyon #toulouse #tbilisi #berlin #munich #hamburg #stuttgart #cologne #frankfu ...
#  "                             Are you ready to learn fast and have a real impact at our brand new Italian office? 🇮🇹  Join our amazing team of Business Analysts and rise to the challenge to evolve in the IT sector! If you have always found it exciting to start in tech sales, we offer an extraordinary chance to learn and grow as a business expert.       What your job will be    You'll be directly in contact with the clients to  implement Odoo  and help them with the good use of Odoo Software (eCommerce, Manufacturing, Inventory, Project, Website, etc.) Therefore, you will analyse their needs and deliver personal training sessions. Basically, you'll be responsible to deliver the best management solution to your customers 🔥     As a Business Analyst, you will also support the growth of our partner network. You will help &amp; coach our partners, from all around the world, to implement their customers projects and to become Odoo Experts. You will also have the opportunity to develop larger accounts (Medium Market &amp; Corporate), deal with companies from 100 employee and manage bigger &amp; long-term projects.  The goal is still to implement our software and deliver tailor-made training.  You could evolve as Project Director 😎     You'll work on various different projects at the same time.You will quickly get involved in your first projects from the very beginning receiving the support from experienced colleagues. You will progressively increase your level of autonomy without forgetting that two heads are better than one 🧠 You won't have time to get bored as each project is different (industry, scope, etc.), and you will learn a lot!     Do you have experience in Accounting, Finance, HR, Supply chain, Manufacturing, e-commerce, Marketing? Even Better. We want our Business Analysts to be able to implement Odoo from A to Z in any company, sector and business area. To do so, bringing people having a few years of experience on the field is necessary as well as an important plus for your application ⚡       Your responsibilities     Gain the trust of your customers  Analyse the customer needs and suggest solutions  Implement the agreed solutions (configuration &amp; development)  Make your customer/partner an Odoo Champion (training)  Follow the project and communicate about its status and the ongoing tasks  Organise and follow up Odoo implementations  Feedback to the Product Owners  Coaching &amp; Training  Feedback for department improvement        Your profile     0 to 5 years of experience  Bachelor's or Master's degree (ideally business-related)   Fluent in Italian (C1-C2) and English   Learn fast &amp; Multitasking  Good communication &amp; negotiation skills  Autonomous, Assertive &amp; Proactive  Affinity with the IT world  Valid work permit for Italy        Nice to have     Fluent in another European language  Experienced in management software implementation  Being certified by a recognized organism (APICS, CFA, ect.)  Technical knowledge (XML, Python, JS)        What is great about this job:     Get the chance to be one of the first Business Analysts and be a pillar in the evolution of the new Odoo subsidiary 🇮🇹  Get real responsibilities and autonomy in a fast evolving company 🚀  Great team of dynamic people in a friendly and open culture  Diversity in the projects  Expand your knowledge of various business industries  Two weeks of intensive functional training with a final certification       At Odoo, we are committed to a diverse, inclusive, and authentic work environment. So if you're interested in this position, but your past experience doesn't perfectly match all the qualifications in the job description, we encourage you to apply anyway. You may be just the right candidate for this or other positions.                          "
#  '                             Line of Service   Advisory   Industry/Sector   Not Applicable   Specialism   Data and Analytics Technologies   Management Level   Associate    Job Description &amp; Summary    PwC, Firma líder mundial en servicios profesionales, se encuentra en un continuo proceso de expansión y crecimiento de sus distintas líneas de negocio.  La División de Consulting está compuesta por más de 900 profesionales que ofrecen servicios de consultoría y asesoramiento empresarial en los ámbitos de Mejora de Procesos y de la Función Financiera, Operating Consulting, Asesoramiento y Planificación Estratégica, Analytics y Business Security Solutions.  En este contexto, queremos incorporar a nuestro equipo de Data&amp;Analytics profesionales para participar en innovadores proyectos para importantes clientes del sector público y privado.  Los profesionales seleccionados pasarán a formar parte del Hub de PwC en Málaga, Centro de Excelencia de tecnologías de Big Data &amp; Analytics en España. Está formado por un equipo multidisciplinar de profesionales de primer nivel, incluyendo Arquitectos Software, Big Data y de Datos, Data Scientist, desarrolladores especializados en Frontend, Backend y Full Stacks, expertos en UX, y especialistas en plataformas Cloud, dando soporte tanto a necesidades internas de la compañía como a proyectos para terceros. En este centro se ha desarrollado y se gestiona un stack completo de Big Data que facilita el trabajo y análisis con grandes volúmenes de datos de forma rápida e intuitiva, lo que facilita la obtención de Insights monetizables por parte de los usuarios del mismo.    Perfil BackEnd:   profesional con al menos 3 años de experiencia en desarrollo con Python. Requisitos:    Ingeniería Superior: Telecomunicaciones, Informática, Matemáticas o similar.   Experiencia en tratamiento de grandes volúmenes de datos, en entornos tradicionales o Big Data.   ETLs.   Desarrollo de software, preferiblemente con Python.   Experiencia en desarrollo de modelos analíticos, machine learning, data mining.   Integración de sistemas.   Bases de datos, tanto NoSQL (Elastic Search, MongoDB,...) como relacionales (Postgre, SQL Server...)   Herramientas de gestión de configuración e integración continua.   Sistema de control de versiones Git.   Metodologías ágiles.   Conocimiento de tecnología Apache Spark y/o Hadoop.   Nivel alto de inglés.     Perfil FrontEnd:   profesional con al menos 3 años de experiencia. Requisitos:    Ing. Telecomunicaciones, Informática, Matemáticas o similar.   Experiencia de 2-3 años demostrable en Proyectos FrontEnd.   Buen dominio de Javascript y TypeScript. Además buen conocimiento de ECMAScript 6.   Experiencia en el desarrollo de aplicaciones Responsive de una sola página, sólida experiencia con Angular 2+.   Experiencia en diseño de soluciones front (Bootstrap o material design).   Experiencia con bibliotecas de gráficos (Highcharts, plotly, D3).   Experiencia con sistemas de control de versiones (Git y GitHub).   Experiencia con metodologías ágiles (marco SCRUM) y prácticas de Integración Continua.   Nivel alto de inglés   Se valorará positivamente experiencia adicional sobre: experiencia en JS frameworks (VueJS, React) y Conocimiento UX/UI (Figma, Sketch, Zeplin)    Perfil Scrum Master:   profesional con 3 - 5 años de experiencia. Requisitos:    Ingeniería Superior: Telecomunicaciones, Informática, Matemáticas o similar.   Experiencia en tratamiento de grandes volúmenes de datos, en entornos tradicionales o Big Data.   Conocimiento en marcos ágiles / scrum y éxito comprobado trabajando en un entorno ágil.   Conocimientos en Python.   Experiencia en desarrollo de modelos analíticos, machine learning, data mining.   Integración de sistemas.   Bases de datos, tanto NoSQL (Elastic Search, MongoDB,...) como relacionales (Postgre, SQL Server...).   Herramientas de gestión de configuración e integración continua.   Metodologías ágiles.   Certificación CSM (Certified Scrum Master).   ...
#  '                              Line of Service  Internal Firm Services     Industry/Sector  Not Applicable     Specialism  IFS - Internal Firm Services - Other     Management Level  Associate     Job Description &amp; Summary  A career in the Chief Data Office within Internal Firm Services will provide you with the opportunity to support our business by delivering excellent data management services. We are looking for an experienced data business process analyst to join our team. In this role you will lead data process alignment and work on data projects. The ideal candidate will have strong business analysis, stakeholder management &amp; process mapping skills. You will play an important role in continuously developing our operations so as to provide the highest quality of data and data management services to enable the business.     Key responsibilities include:      Develop process maps and data flows   Develop, maintain and socialise data policies and processes to a high standard   Coordinate with business stakeholders to implement processes that align across the business in a manner that is concise and meets the business and data needs   Understand the business implications of the application of data within the business operations solutions ecosystem and assess impacts of changes in the ecosystem on data and underlying processes   Apply understanding of data quality and control to establish strong data management activities including but not limited to quality control checks and reconciliations   Review internal process efficiencies and making recommendations for process improvement   Lead data projects and provide support across all data services   Participate in team projects planning and prioritisation activities       Education/Professional Qualifications:     Candidates to have a third level qualification (a qualification in data management/compliance desirable)      Experience Required:     2 years+ (business analyst and working on projects)   Strong experience of data quality control and reconciliation   Good experience of developing process maps   Relevant industry experience in describing end to end business processes, identifying challenges and solutions as well as implementing and reviewing    Experience of working with a high performing team and delivering to deadlines   Solid understanding of data systems, including data relationships and data modelling with the ability to learn and understand various data environments      Personal Qualities:     Ability to handle multi-tasking environment, meet deadlines, and work with a wide range stakeholders   Excellent analytical and problem solving skills   Excellent communication skills both verbal and written, with storytelling   Demonstrates enthusiasm &amp; commitment to work   Ability to adapt to change and escalate problems as appropriate using initiative and discretion   Ability to develop business relationships internally and externally    Demonstrates a commitment to quality and integrity    Proactive work approach and ability to demonstrate good judgement      Unlock your potential with PwC Ireland    We believe that challenges are better solved together. We’re inspiring and empowering our people to change the world. Powered by the latest technology, you’ll be a part of amazing teams encouraged to collaborate and innovate in a way that creates powerful solutions and makes a positive impact. This purpose-led work, and our continuous development and encouragement, will help unlock your potential and take your career to the next level.    Enjoy PwC’s perks    We reward your impact, and support your wellbeing, through a competitive compensation package, inclusive employee benefits and flexibility programs that will help you thrive in work and life. Learn more about us at Life@PwC. (https://www.pwc.ie/careers-ie/life-at-pwc.html).    Being appreciated for being you    Our most valuable asset is our people and we recognise you for it - ensuring you feel like you b ...
# Столбец: applicants
# Количество уникальных неявных пропущенных значений в столбце: 0
# []

# %%
# возвращаем тип данных для столбца applicants
df['applicants'] = df['applicants'].astype('float')

# %%
# найдем задублированные строки

df.duplicated().sum()
# Out:
# 112

# %% [markdown]
# **Вывод**:
#
# - почти во всех столбцах (8 из 9) тип данных - строковый, в столбце applicants тип данных - вещественный. Тип данных во всех столбцах - корректный.
# - наименования столбцов также представлены корректно (нижний регистр, нижнее подчеркивание в случае нескольких слов)
# - в столбцах applicants (количество поданных заявок) и company_name имеются пропущенные значения (160 и 2 соответственно). Пропущенных значений в столбце сompany_name - всего два и название компании невозможно чем-то заменить. Имеет смысл рассмотреть столбец applicants
# - в датасете имеются 112 строк-дубликатов
# - в столбцах employment_type (тип занятости), employee_qty (количество сотрудников), company_field (область компании) пропуски заменены на not specified, т.е. в Linkedin компании решили не указывать эти данные
# - в столбце skills есть неявные пропуски (None), однако, не целесообразно заполнять ячейки с пропущенными значениями, т.к. имеет этот столбец не будет анализироваться, а во-вторых, в этом столбце могут быть совершенно разная информация, в-третьих, если мы заполним данными из столбца job_description, то столбец skills просто продублирует job_description, а нам нужно уникальные данные из столбца skills
# - в столбце job_description было найдены неявные пропуски, но они фигурируют в самих описаниях вакансии, поэтому можно сказать, что пропусков в столбце job_description - нет

# %% [markdown]
# **Причин пропуска значений в столбце applicants может быть 2:**
# 1) NaN = 0
#
# 2) Данные по этому параметру не спарсились
#
# Поскольку данные по этому столбцу не повлияют на точность результатов (количество поданных заявок на вакансию нам не интересны), то можем сделать допущение, что NaN - это ноль.

# %%
# проверим, является ли пропущенные значения в столбце applicants (количество поданных заявок) нулем 
# (т.е. на данную вакансию никто не откликнулся)

df[df['applicants']==0]
# Out:
# Empty DataFrame
# Columns: [title, location, country, employment_type, company_name, employee_qty, company_field, skills, job_description, applicants]
# Index: []

# %%
# заполним пропущенные значения в столбце applicants нулем

df['applicants'] = df['applicants'].fillna(0)

# %% [markdown]
# **Вывод**:
#
# - Пропущенные значения в столбце applicants - это ноль, поэтому пропущенные значения заменили нулем.

# %% [markdown]
# **Найдем неявные дубликаты в столбцах и заменим их**

# %%
# выявим количество уникальных наименований в столбцах
for i in df.columns:
    print('Столбец',i,'\n','Количество уникальных значений:',df[i].nunique(),'\n')
# Out:
# Столбец title
#  Количество уникальных значений: 560
#
# Столбец location
#  Количество уникальных значений: 428
#
# Столбец country
#  Количество уникальных значений: 72
#
# Столбец employment_type
#  Количество уникальных значений: 4
#
# Столбец company_name
#  Количество уникальных значений: 669
#
# Столбец employee_qty
#  Количество уникальных значений: 19
#
# Столбец company_field
#  Количество уникальных значений: 122
#
# Столбец skills
#  Количество уникальных значений: 617
#
# Столбец job_description
#  Количество уникальных значений: 812
#
# Столбец applicants
#  Количество уникальных значений: 178

# %% [markdown]
# Поскольку неявные дубликаты смотрятся вручную, то проанализируем и заменим в случае необходимости неявные дубликаты в столбцах country, employment_type, employee_qty и company_field

# %%
# создадим функцию для поиска неявных дубликатов
def duplicated_column(i):
    print(sorted(df[i].unique()))

# %%
# создадим функцию для замены неявных дубликатов
def replace_name(data, i,name_old,name_new):
    data[i] = data[i].str.replace(name_old,name_new,regex=True).copy()

# %% [markdown]
# Столбец 'country'

# %%
# выведем уникальные значения для поиска неявных дубликатов
duplicated_column('country')
# Out:
# [' Austria', ' Belgium', ' Bulgaria', ' Croatia', ' Czechia', ' Denmark', ' Estonia', ' Finland', ' France', ' Germany', ' Greece', ' Hungary', ' Ireland', ' Italy', ' Latvia', ' Lithuania', ' Luxembourg', ' Malta', ' Monaco', ' Netherlands', ' Norway', ' Poland', ' Portugal', ' Romania', ' Slovakia', ' Spain', ' Sweden', ' Switzerland', ' United Kingdom', 'Amsterdam Area', 'Athens Metropolitan Area', 'Berlin Metropolitan Area', 'Brussels Metropolitan Area', 'Bulgaria', 'Cologne Bonn Region', 'Copenhagen Metropolitan Area', 'Denmark', 'Eindhoven Area', 'Finland', 'France', 'Germany', 'Greater Banska Bystrica Area', 'Greater Barcelona Metropolitan Area', 'Greater Dijon Area', 'Greater Lyon Area', 'Greater Madrid Metropolitan Area', 'Greater Milan Metropolitan Area', 'Greater Munich Metropolitan Area', 'Greater Munster Area', 'Greater Nuremberg Metropolitan Area', 'Greater Oslo Region', 'Greater Palma de Mallorca Metropolitan Area', 'Greater Paris Metropolitan Region', 'Greater Pau Area', 'Greater Verona Metropolitan Area', 'Hungary', 'Iasi Metropolitan Area', 'Ireland', 'Italy', 'Krakow Metropolitan Area', 'Lisbon Metropolitan Area', 'Lithuania', 'Netherlands', 'Poland', 'Portugal', 'Prague Metropolitan Area', 'Romania', 'Rotterdam and The Hague', 'Spain', 'Stuttgart Region', 'Warsaw Metropolitan Area', 'Wroclaw Metropolitan Area']

# %%
# заменим неявные дубликаты
replace_name(df,'country','Amsterdam Area','Netherlands')
replace_name(df,'country','Athens Metropolitan Area', 'Greece')
replace_name(df,'country','Berlin Metropolitan Area', 'Germany')
replace_name(df,'country','Brussels Metropolitan Area', 'Belgium')
replace_name(df,'country','Cologne Bonn Region', 'Germany')
replace_name(df,'country','Copenhagen Metropolitan Area', 'Denmark')
replace_name(df,'country','Eindhoven Area', 'Netherlands')
replace_name(df,'country','Greater Banska Bystrica Area', 'Slovakia')
replace_name(df,'country','Greater Barcelona Metropolitan Area', 'Spain')
replace_name(df,'country','Greater Dijon Area', 'France')
replace_name(df,'country','Greater Lyon Area', 'France')
replace_name(df,'country','Greater Madrid Metropolitan Area', 'Spain')
replace_name(df,'country','Greater Milan Metropolitan Area', 'Italy')
replace_name(df,'country','Greater Munich Metropolitan Area', 'Germany')
replace_name(df,'country','Greater Munster Area', 'Ireland')
replace_name(df,'country','Greater Nuremberg Metropolitan Area', 'Germany')
replace_name(df,'country','Greater Oslo Region', 'Norway')
replace_name(df,'country','Greater Palma de Mallorca Metropolitan Area', 'Spain')
replace_name(df,'country','Greater Paris Metropolitan Region','France')
replace_name(df,'country','Greater Pau Area','France')
replace_name(df,'country','Greater Verona Metropolitan Area', 'Italy')
replace_name(df,'country','Iasi Metropolitan Area', 'Romania')
replace_name(df,'country','Krakow Metropolitan Area', 'Poland')
replace_name(df,'country','Lisbon Metropolitan Area', 'Portugal')
replace_name(df,'country','Prague Metropolitan Area', 'Czechia')
replace_name(df,'country','Rotterdam and The Hague', 'Netherlands')
replace_name(df,'country','Stuttgart Region', 'Germany')
replace_name(df,'country','Warsaw Metropolitan Area', 'Poland')
replace_name(df,'country','Wroclaw Metropolitan Area', 'Poland')
replace_name(df,'country',' ', '')
replace_name(df,'country','UnitedKingdom', 'United Kingdom')

# %%
# выведем уникальные значения для поиска неявных дубликатов
duplicated_column('country')
# Out:
# ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Monaco', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']

# %% [markdown]
# Столбец 'employment_type'

# %%
# выведем уникальные значения для поиска неявных дубликатов

duplicated_column('employment_type')
# Out:
# ['Hybrid', 'On-site', 'Remote', 'not specified']

# %% [markdown]
# Столбец 'employee_qty'

# %%
# выведем уникальные значения для поиска неявных дубликатов

duplicated_column('employee_qty')
# Out:
# ['1,001-5,000 employees', '1-10 employees', '10,001+ employees', '11-50 employees', '201-500 employees', '5,001-10,000 employees', '501-1,000 employees', '51-200 employees', 'Retail Apparel and Fashion', 'Romain GUIHENEUF is hiring for this job', 'See how you compare to 10 applicants. Try Premium for free', 'See how you compare to 13 applicants. Try Premium for free', 'See how you compare to 19 applicants. Try Premium for free', 'See how you compare to 22 applicants. Try Premium for free', 'See how you compare to 4 applicants. Try Premium for free', 'See how you compare to 9 applicants. Try Premium for free', 'See recent hiring trends for Devonshire Hayes Recruitment Specialists Ltd. Try Premium for free', 'Svein Grande is hiring for this job', 'not specified']

# %%
# заменим "See how you compare to ... applicants. Try Premium for free",
# "See recent hiring trends for Devonshire Hayes Recruitment Specialists Ltd. Try Premium for free",
# "Svein Grande is hiring for this job",
# "Romain GUIHENEUF is hiring for this job" и
# "Retail Apparel and Fashion" (дублирование из столбца на company_field) на "not specified",
# поскольку это то же самое, что "не указано"

replace_name(df,'employee_qty','See how you compare to 10 applicants. Try Premium for free','not specified')
replace_name(df,'employee_qty','See how you compare to 13 applicants. Try Premium for free','not specified')
replace_name(df,'employee_qty','See how you compare to 19 applicants. Try Premium for free','not specified')
replace_name(df,'employee_qty','See how you compare to 22 applicants. Try Premium for free','not specified')
replace_name(df,'employee_qty','See how you compare to 4 applicants. Try Premium for free','not specified')
replace_name(df,'employee_qty','See how you compare to 9 applicants. Try Premium for free','not specified')
replace_name(df,'employee_qty','See recent hiring trends for Devonshire Hayes Recruitment Specialists Ltd. Try Premium for free',\
             'not specified')
replace_name(df,'employee_qty','Svein Grande is hiring for this job','not specified')
replace_name(df,'employee_qty','Romain GUIHENEUF is hiring for this job','not specified')
replace_name(df,'employee_qty','Retail Apparel and Fashion','not specified')

# %%
# проверим, что замена осуществлена

duplicated_column('employee_qty')
# Out:
# ['1,001-5,000 employees', '1-10 employees', '10,001+ employees', '11-50 employees', '201-500 employees', '5,001-10,000 employees', '501-1,000 employees', '51-200 employees', 'not specified']

# %% [markdown]
# Столбец company_field

# %%
# выведем уникальные значения для поиска неявных дубликатов
duplicated_column('company_field')
# Out:
# ['1,001-5,000 employees', '1-10 employees', '11-50 employees', '201-500 employees', '501-1,000 employees', '51-200 employees', 'Advertising Services', 'Airlines and Aviation', 'Apparel & Fashion', 'Appliances, Electrical, and Electronics Manufacturing', 'Armed Forces', 'Automation Machinery Manufacturing', 'Automotive', 'Aviation and Aerospace Component Manufacturing', 'Banking', 'Biotechnology Research', 'Book and Periodical Publishing', 'Business Consulting and Services', 'Chemical Manufacturing', 'Computer Games', 'Computer and Network Security', 'Computers and Electronics Manufacturing', 'Construction', 'Consumer Goods', 'Consumer Services', 'Cosmetics', 'Dairy Product Manufacturing', 'Defense & Space', 'Defense and Space Manufacturing', 'Education Administration Programs', 'Entertainment Providers', 'Environmental Services', 'Farming', 'Financial Services', 'Food & Beverages', 'Food Production', 'Food and Beverage Manufacturing', 'Food and Beverage Services', 'Gambling Facilities and Casinos', 'Glass, Ceramics and Concrete Manufacturing', 'Government Administration', 'Higher Education', 'Hospitality', 'Hospitals and Health Care', 'Human Resources', 'Human Resources Services', 'IT Services and IT Consulting', 'Individual and Family Services', 'Industrial Machinery Manufacturing', 'Information Services', 'Information Technology & Services', 'Insurance', 'International Affairs', 'International Trade and Development', 'Internet Marketplace Platforms', 'Internet Publishing', 'Investment Banking', 'Investment Management', 'Law Enforcement', 'Law Practice', 'Leisure, Travel & Tourism', 'Machinery Manufacturing', 'Manufacturing', 'Market Research', 'Mechanical Or Industrial Engineering', 'Medical Equipment Manufacturing', 'Mental Health Care', 'Motor Vehicle Manufacturing', 'Motor Vehicle Parts Manufacturing', 'Musicians', 'Newspaper Publishing', 'Non-profit Organizations', 'Oil and Gas', 'Outsourcing and Offshoring Consulting', 'Packaging and Containers Manufacturing', 'Performing Arts', 'Personal Care Product Manufacturing', 'Pharmaceutical Manufacturing', 'Philanthropic Fundraising Services', 'Primary Metal Manufacturing', 'Printing Services', 'Professional Services', 'Public Relations and Communications Services', 'Railroad Equipment Manufacturing', 'Real Estate', 'Renewable Energy Power Generation', 'Renewable Energy Semiconductor Manufacturing', 'Research', 'Research Services', 'Restaurants', 'Retail', 'Retail Apparel and Fashion', 'Retail Groceries', 'Retail Health and Personal Care Products', 'Retail Luxury Goods and Jewelry', 'Retail Office Equipment', 'Romain GUIHENEUF is hiring for this job', 'See how you compare to 10 applicants. Try Premium for free', 'See how you compare to 13 applicants. Try Premium for free', 'See how you compare to 19 applicants. Try Premium for free', 'See how you compare to 22 applicants. Try Premium for free', 'See how you compare to 4 applicants. Try Premium for free', 'See how you compare to 9 applicants. Try Premium for free', 'See recent hiring trends for Devonshire Hayes Recruitment Specialists Ltd. Try Premium for free', 'Semiconductor Manufacturing', 'Software Development', 'Spectator Sports', 'Sporting Goods Manufacturing', 'Staffing and Recruiting', 'Svein Grande is hiring for this job', 'Technology, Information and Internet', 'Telecommunications', 'Translation and Localization', 'Transportation, Logistics, Supply Chain and Storage', 'Travel Arrangements', 'Truck Transportation', 'Utilities', 'Wellness and Fitness Services', 'Wholesale', 'Wholesale Building Materials', 'Wind Electric Power Generation', 'not specified']

# %% [markdown]
# Видим, что в данном столбце есть значения, которые не соответствуют сути данного столбца (про количество сотрудников). Прежде чем убирать эти данные, проверим, что в столбце employee_qty все заполнено

# %%
# убеждаемся, что в столбце employee_qty все заполнено
df[(df['company_field'] == '1,001-5,000 employees')|(df['company_field'] == '1-10 employees')|\
   (df['company_field'] == '11-50 employees')|(df['company_field'] == '201-500 employees')|\
   (df['company_field'] == '501-1,000 employees')|(df['company_field'] == '51-200 employees')]
# Out:
#                                                  title  \
# 34                                        Data Analyst
# 44                                        Data Analyst
# 49                                        Data Analyst
# 58                                        Consultor BI
# 61                                        Data Analyst
# 137                                       Data analyst
# 258                               Data Analyst (m/w/d)
# 282                            Data Governance analyst
# 355                            Datový analytik/vývojář
# 401    Data Analist - startersfunctie (Dutch speaking)
# 452        Junior project manager - Categoria Protetta
# 453                            Junior Business Analyst
# 454                         Softwareentwickler (m/w/d)
# 473                    Medewerker verkoop binnendienst
# 474                      BÜROKRAFT (M/W/D) IN GARCHING
# 475                      Mitarbeiter Marketing (m/w/d)
# 477              Ingenieur Softwareentwicklung (m/w/d)
# 478  Projektmanager / Projektleiter Automotive (m/w/d)
# 479                  ESG Analyst - Real Estate (m/w/d)
# 480              APM Software Development & Operations
# 481                                         Accountant
# 483                  Mitarbeiter Marketing B2B (m/w/d)
# 484  Chargé de projets Sustainability F/H en appren...
# 485                                      Test Engineer
# 486                                   Systemutvecklare
# 487                              IT-Spezialist (m/w/d)
# 489                         Projektleitung Seiltechnik
# 490                     Säljare till Skaraborgsområdet
# 491                       Medewerker Cursuscoördinatie
# 492                      Chef de Projet Réhabilitation
# 497                               Reporting Specialist
# 498                                    Product Manager
# 499                      IT Support Analyst, Global IT
# 508          Chemical development process  Lab analyst
# 509                                    DATA ANALYST IT
# 515                               Composiet medewerker
# 520                                   Sales Specialist
# 533                               System Developer GIS
# 534                               Analista de Software
# 584                                      Data Engineer
# 624                                    Data Specialist
# 630                                     Data Scientist
# 648                     Business Intelligence Engineer
# 659                                     Data Scientist
# 665                                      Data Engineer
# 698          Information Technology Support Specialist
# 730                    Information Technology Engineer
# 797                                Analista funzionale
# 798                Programmatore / Analista funzionale
# 822                                Analista funzionale
# 824          Chargé de projet validation stérilisation
# 837                                Front-end Developer
# 874                                  Mid Data Engineer
# 903                                     Data Scientist
# 975                             Database Administrator
# 977                       Process Performance Engineer
# 981                                      Data Engineer
# 997                               Analista de datos BI
#
#                          location      country employment_type  \
# 34                        Vilnius    Lithuania          Hybrid
# 44                          Milan        Italy          Hybrid
# 49                         France       France          Remote
# 58                      Barcelona        Spain          Hybrid
# 61                        Hungary      Hungary          Remote
# 137                      Bordeaux       France          Hybrid
# 258                    Düsseldorf      Germany         On-site
# 282                     Vilvoorde      Belgium         On-site
# 355      Prague Metropolitan Area      Czechia          Hybrid
# 401                     The Hague  Netherlands          Hybrid
# 452                         Milan        Italy          Hybrid
# 453                      Lombardy        Italy         On-site
# 454                        Coburg      Germany          Hybrid
# 473                      Doesburg  Netherlands         On-site
# 474                        Munich      Germany         On-site
# 475                  Tussenhausen      Germany         On-site
# 477                   Hückelhoven      Germany          Hybrid
# 478                      Eisenach      Germany          Hybrid
# 479                    Luxembourg   Luxembourg         On-site
# 480                        Berlin      Germany          Hybrid
# 481              Stockholm County       Sweden          Remote
# 483                        Munich      Germany          Hybrid
# 484                       Erstein       France         On-site
# 485                   Szombathely      Hungary         On-site
# 486                       Ronneby       Sweden         On-site
# 487                      Elmshorn      Germany          Hybrid
# 489                        Bremen      Germany         On-site
# 490                     Lidköping       Sweden          Hybrid
# 491                           Ede  Netherlands          Hybrid
# 492                         Rouen       France         On-site
# 497                       Tallinn      Estonia          Hybrid
# 498                     Amsterdam  Netherlands          Hybrid
# 499                         Farum      Denmark         On-site
# 508               Braine-l’Alleud      Belgium         On-site
# 509         Vila Nova de Cerveira     Portugal         On-site
# 515                      Lelystad  Netherlands         On-site
# 520                         Marsa        Malta         On-site
# 533                           Åre       Sweden          Hybrid
# 534                  Bilbao-Bilbo        Spain          Hybrid
# 584                         Porto     Portugal          Hybrid
# 624      Athens Metropolitan Area       Greece          Hybrid
# 630                        Prague      Czechia          Hybrid
# 648               Palaión Fáliron       Greece         On-site
# 659                       Finland      Finland          Remote
# 665                        Madrid        Spain          Hybrid
# 698           Greater Oslo Region       Norway         On-site
# 730                       Piraeus       Greece         On-site
# 797                     Pordenone        Italy         On-site
# 798                         Turin        Italy          Hybrid
# 822                     Pordenone        Italy         On-site
# 824                        Bernay       France         On-site
# 837                         Porto     Portugal          Hybrid
# 874                      Portugal     Portugal          Remote
# 903                         Milan        Italy          Hybrid
# 975                         Porto     Portugal         On-site
# 977                     Amsterdam  Netherlands          Hybrid
# 981  Copenhagen Metropolitan Area      Denmark         On-site
# 997                      Valencia        Spain          Hybrid
#
#                                           company_name           employee_qty  \
# 34                               Havas Group Lithuania       51-200 employees
# 44                                            SPIN 360        11-50 employees
# 49                                            Hubble_s        11-50 employees
# 58                                  Konozca Consulting        11-50 employees
# 61                                            Peroptyx        11-50 employees
# 137                                        RH Partners       51-200 employees
# 258                            Benchmark International      201-500 employees
# 282                                            Streamz      201-500 employees
# 355                                Direct technologies       51-200 employees
# 401                                              Whooz        11-50 employees
# 452                                             BluCRM       51-200 employees
# 453                                   Consulcesi Group    501-1,000 employees
# 454                                         KAPP NILES  1,001-5,000 employees
# 473                            Wigersma & Sikkema B.V.        11-50 employees
# 474                                    FITCOMPANY GmbH      201-500 employees
# 475                            RUF Briquetting Systems       51-200 employees
# 477                            HUBER+SUHNER BKtel GmbH       51-200 employees
# 478                   REBO Lighting & Electronics GmbH      201-500 employees
# 479                                       Empira Group      201-500 employees
# 480                                         Perform IT       51-200 employees
# 481                                         HansaWorld      201-500 employees
# 483                                         Simovative       51-200 employees
# 484                             WURTH INDUSTRIE FRANCE       51-200 employees
# 485                                     Ivy Technology  1,001-5,000 employees
# 486                                   NovaCast Systems        11-50 employees
# 487                                      Teppich-Kibek    501-1,000 employees
# 489                                     Gleistein GmbH      201-500 employees
# 490                    Linde Material Handling Sverige      201-500 employees
# 491                        ROVC Technische Opleidingen       51-200 employees
# 492                                            CORHEME         1-10 employees
# 497                                            BaltCap        11-50 employees
# 498                                  Spinnin'​ Records       51-200 employees
# 499                                            Danelec       51-200 employees
# 508                  Eurofins PSS Insourcing Solutions  1,001-5,000 employees
# 509                               Potenzia Consultores         1-10 employees
# 515                                      Stratos Yacht         1-10 employees
# 520                                       Yellow Malta        11-50 employees
# 533                                        Sunna Group         1-10 employees
# 534                                      Deusto SEIDOR       51-200 employees
# 584                                         BrandDelta        11-50 employees
# 624                              Modelity Technologies       51-200 employees
# 630                                    Gauss & Neumann        11-50 employees
# 648           Altair Travel Agency S.A. - Tripair GmbH       51-200 employees
# 659  Centre for Research on Energy and Clean Air (C...         1-10 employees
# 665                                          El Cactus         1-10 employees
# 698                          Oslo International School       51-200 employees
# 730      Piraeus Port Authority-PPA/OLP-COSCO Shipping  1,001-5,000 employees
# 797                                          Magia Srl        11-50 employees
# 798                           Zanichelli editore S.p.A      201-500 employees
# 822                                          Magia Srl        11-50 employees
# 824                                      Steriservices       51-200 employees
# 837                          Fraunhofer Portugal AICOS       51-200 employees
# 874                                Scotty Technologies        11-50 employees
# 903                                              CGnal        11-50 employees
# 975                           AIMS International Spain        11-50 employees
# 977                                 Tony's Chocolonely       51-200 employees
# 981                                        Radiobotics        11-50 employees
# 997                                           Infoport       51-200 employees
#
#              company_field                                             skills  \
# 34        51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 44         11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 49         11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 58         11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 61         11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 137       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 258      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 282      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 355       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 401        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 452       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 453    501-1,000 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 454  1,001-5,000 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 473        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 474      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 475       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 477       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 478      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 479      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 480       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 481      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 483       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 484       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 485  1,001-5,000 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 486        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 487    501-1,000 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 489      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 490      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 491       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 492         1-10 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 497        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 498       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 499       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 508  1,001-5,000 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 509         1-10 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 515         1-10 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 520        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 533         1-10 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 534       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 584        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 624       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 630        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 648       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 659         1-10 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 665         1-10 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 698       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 730  1,001-5,000 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 797        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 798      201-500 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 822        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 824       51-200 employees                                               None
# 837       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 874        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 903        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 975        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 977       51-200 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 981        11-50 employees  <span class="visually-hidden"><!-- -->Skills: ...
# 997       51-200 employees                                               None
#
#                                        job_description  applicants
# 34                                 What You Will Do...        98.0
# 44                                 About the Compan...       196.0
# 49                                 Data Analyst - I...         0.0
# 58                                 Konozca crece  y...        86.0
# 61                                For thousands of ...       177.0
# 137                               Notre client est ...         0.0
# 258                               Über uns:     Mit...       102.0
# 282                               Streamz is de Vla...         4.0
# 355                                Hledáme data ana...         4.0
# 401                                Van leuk werk, k...        19.0
# 452                                Chi siamo   Siam...        14.0
# 453                               Within the  SAR D...        97.0
# 454                               KAPP NILES ist ei...        19.0
# 473                               Wigersma &amp; Si...         1.0
# 474                                Aufgabenbereich ...         8.0
# 475                              WERDE TEIL DER RUF...         9.0
# 477                               Wir suchen an uns...        22.0
# 478                               Wir suchen Dich a...        25.0
# 479                               Empira Investment...        42.0
# 480                                Who are Perform ...        68.0
# 481                               Join us to become...       146.0
# 483                                     This job is...        32.0
# 484                                WÜRTH INDUSTRIE ...        54.0
# 485                               Built on a founda...        13.0
# 486                                Systemutvecklare...        16.0
# 487                               Wie wird aus eine...         8.0
# 489                                Hast du den Mut,...        40.0
# 490                                 Brinner du för ...         4.0
# 491                                Als medewerker c...         1.0
# 492                                Poste : Chef de ...        24.0
# 497                                Your main role a...        15.0
# 498                                 ABOUT SPINNIN’ ...       115.0
# 499                                Do you have a pa...        12.0
# 508                                 Company Descrip...        62.0
# 509                               O nosso cliente, ...        17.0
# 515                                Stratos Yacht B....         2.0
# 520                               Yellow Malta woul...        63.0
# 533                               Vill Du bidra til...        28.0
# 534                               GRUPO SEIDOR, Mul...        32.0
# 584                                Company Descript...        43.0
# 624                                Job summary    A...       116.0
# 630                               At Gauss &amp; Ne...       139.0
# 648                               Responsibilities:...        11.0
# 659                               CREA ( Centre for...       182.0
# 665                               DATA ENGINEER    ...        60.0
# 698                                IT SUPPORT SPECI...        98.0
# 730                               Job description  ...        77.0
# 797                                Magia  S.r.l. è ...        30.0
# 798                               Siamo alla ricerc...        87.0
# 822                                Magia  S.r.l. è ...        30.0
# 824                               Dans le but de re...        38.0
# 837                                Job Title:    Fr...       126.0
# 874                               Hey! We are Scott...        94.0
# 903                               The role of Data ...       117.0
# 975                               Our client  -DR. ...        21.0
# 977                               At Tony’s Chocolo...        73.0
# 981                                 Are you a data ...        44.0
# 997                                Funciones   · Bu...       198.0

# %%
# заменим данные из данного столбца с данными о количестве сотрудников на 'not specified'
replace_name(df,'company_field','1,001-5,000 employees','not specified')
replace_name(df,'company_field','1-10 employees','not specified')
replace_name(df,'company_field','11-50 employees','not specified')
replace_name(df,'company_field','201-500 employees','not specified')
replace_name(df,'company_field','501-1,000 employees','not specified')
replace_name(df,'company_field','51-200 employees','not specified')

# %%
# заменим See how you compare to ... applicants. Try Premium for free и 
# Romain GUIHENEUF is hiring for this job на not specified и т.д.

replace_name(df,'company_field','See how you compare to 10 applicants. Try Premium for free','not specified')
#replace_name('employee_qty',list_name,'not specified')
replace_name(df,'company_field','See how you compare to 13 applicants. Try Premium for free','not specified')
replace_name(df,'company_field','See how you compare to 19 applicants. Try Premium for free','not specified')
replace_name(df,'company_field','See how you compare to 22 applicants. Try Premium for free','not specified')
replace_name(df,'company_field','See how you compare to 4 applicants. Try Premium for free','not specified')
replace_name(df,'company_field','See how you compare to 9 applicants. Try Premium for free','not specified')
replace_name(df,'company_field','See recent hiring trends for Devonshire Hayes Recruitment Specialists Ltd. Try Premium for free',\
             'not specified')
replace_name(df,'company_field','Svein Grande is hiring for this job','not specified')
replace_name(df,'company_field','Romain GUIHENEUF is hiring for this job','not specified')

# %%
# проверим, что замена произошла
duplicated_column('company_field')
# Out:
# ['Advertising Services', 'Airlines and Aviation', 'Apparel & Fashion', 'Appliances, Electrical, and Electronics Manufacturing', 'Armed Forces', 'Automation Machinery Manufacturing', 'Automotive', 'Aviation and Aerospace Component Manufacturing', 'Banking', 'Biotechnology Research', 'Book and Periodical Publishing', 'Business Consulting and Services', 'Chemical Manufacturing', 'Computer Games', 'Computer and Network Security', 'Computers and Electronics Manufacturing', 'Construction', 'Consumer Goods', 'Consumer Services', 'Cosmetics', 'Dairy Product Manufacturing', 'Defense & Space', 'Defense and Space Manufacturing', 'Education Administration Programs', 'Entertainment Providers', 'Environmental Services', 'Farming', 'Financial Services', 'Food & Beverages', 'Food Production', 'Food and Beverage Manufacturing', 'Food and Beverage Services', 'Gambling Facilities and Casinos', 'Glass, Ceramics and Concrete Manufacturing', 'Government Administration', 'Higher Education', 'Hospitality', 'Hospitals and Health Care', 'Human Resources', 'Human Resources Services', 'IT Services and IT Consulting', 'Individual and Family Services', 'Industrial Machinery Manufacturing', 'Information Services', 'Information Technology & Services', 'Insurance', 'International Affairs', 'International Trade and Development', 'Internet Marketplace Platforms', 'Internet Publishing', 'Investment Banking', 'Investment Management', 'Law Enforcement', 'Law Practice', 'Leisure, Travel & Tourism', 'Machinery Manufacturing', 'Manufacturing', 'Market Research', 'Mechanical Or Industrial Engineering', 'Medical Equipment Manufacturing', 'Mental Health Care', 'Motor Vehicle Manufacturing', 'Motor Vehicle Parts Manufacturing', 'Musicians', 'Newspaper Publishing', 'Non-profit Organizations', 'Oil and Gas', 'Outsourcing and Offshoring Consulting', 'Packaging and Containers Manufacturing', 'Performing Arts', 'Personal Care Product Manufacturing', 'Pharmaceutical Manufacturing', 'Philanthropic Fundraising Services', 'Primary Metal Manufacturing', 'Printing Services', 'Professional Services', 'Public Relations and Communications Services', 'Railroad Equipment Manufacturing', 'Real Estate', 'Renewable Energy Power Generation', 'Renewable Energy Semiconductor Manufacturing', 'Research', 'Research Services', 'Restaurants', 'Retail', 'Retail Apparel and Fashion', 'Retail Groceries', 'Retail Health and Personal Care Products', 'Retail Luxury Goods and Jewelry', 'Retail Office Equipment', 'Semiconductor Manufacturing', 'Software Development', 'Spectator Sports', 'Sporting Goods Manufacturing', 'Staffing and Recruiting', 'Technology, Information and Internet', 'Telecommunications', 'Translation and Localization', 'Transportation, Logistics, Supply Chain and Storage', 'Travel Arrangements', 'Truck Transportation', 'Utilities', 'Wellness and Fitness Services', 'Wholesale', 'Wholesale Building Materials', 'Wind Electric Power Generation', 'not specified']

# %% [markdown]
# **Вывод:**
# - в столбцах company_field, employee_qty и country произведена замена неявных дубликатов

# %% [markdown]
# **Создание новой таблицы, где вакансии будут только в сфере Дата аналитики и Дата сайнтса**

# %%
# приведем к нижнему регистру значения столбцов (job_description, skills) для упрощения работы с ними 
# (для вычленения хард скиллов)

def lowers(i):
    df[i] = df[i].str.lower()

# %%
lowers('job_description')
lowers('skills')
lowers('title')

# %%
# создадим новую таблицу, где будут данные только по дата аналитикам и дата сайнтистам

df_new = df.loc[df['title'].str.contains('anal') | df['title'].str.contains('scient')]

# %%
data.shape[0]
# Out:
# 998

# %% [markdown]
# **Проверка на количества оставшихся данных**

# %%
print('Было {a} строк, стало {b} строк, что составляет {c:.2%} от изначального количества'.format(a = data.shape[0],\
                                                                                            b = df_new.shape[0],\
                                                                                            c = df_new.shape[0]/data.shape[0]))
# Out:
# Было 998 строк, стало 807 строк, что составляет 80.86% от изначального количества

# %% [markdown]
# **Вывод:**
# - осталось 81% от изначального объема.

# %% [markdown]
# **Скорректируем индексы после фильтрации и выведение их в качества столбца для идентификации вакансии**

# %%
# корректировка индексов с удалением старых индексов и создание столбца с новыми индексами
df_new = df_new.reset_index(drop=True)#.reset_index()
df_new = df_new.reset_index().rename(columns = {'index':'number_vacancy'})

# проверка
df_new.tail(5)
# Out:
#      number_vacancy                                              title  \
# 802             802                                  marketing analyst
# 803             803  emerton data: data scientist & strategy consul...
# 804             804                               stage | data analyst
# 805             805                                business-analyst:in
# 806             806                               analista de datos bi
#
#                              location    country employment_type  \
# 802                           Vilnius  Lithuania          Hybrid
# 803                             Paris     France          Hybrid
# 804                          Vermezzo      Italy          Hybrid
# 805  Greater Munich Metropolitan Area    Germany          Hybrid
# 806                          Valencia      Spain          Hybrid
#
#          company_name         employee_qty  \
# 802              Avon    10,001+ employees
# 803           Emerton     51-200 employees
# 804         CPM Italy     51-200 employees
# 805  Computer Futures  501-1,000 employees
# 806          Infoport     51-200 employees
#
#                            company_field  \
# 802  Personal Care Product Manufacturing
# 803     Business Consulting and Services
# 804                               Retail
# 805        IT Services and IT Consulting
# 806                        not specified
#
#                                                 skills  \
# 802  <span class="visually-hidden"><!-- -->skills: ...
# 803  <span class="visually-hidden"><!-- -->skills: ...
# 804  <span class="visually-hidden"><!-- -->skills: ...
# 805  <span class="visually-hidden"><!-- -->skills: ...
# 806                                               none
#
#                                        job_description  applicants
# 802                              you’ve picked a gr...        73.0
# 803                               visit:  emerton-d...       188.0
# 804                                     this job is...         0.0
# 805                               do you want to wo...        51.0
# 806                                funciones   · bu...       198.0

# %% [markdown]
# **Выделение хард скиллов**

# %%
# создадим список с перечнем хард скиллов, которые будут вычленяться из столбца job_description
skills = [
    ' a/b testing', ' ab testing', ' actian', ' adobe analytics', ' adobe audience manager ',
    ' adobe experience platform', ' adobe launch ', ' adobe target ', ' ai ', 'airflow ',
    ' alooma ', ' alteryx', ' amazon machine learning ', ' amazon web services ', ' aml ',
    ' amplitude ', ' ansible ', ' apache camel ', ' apache nifi ', ' apache spark ',
    ' api ', ' asana ', ' auth0 ', ' aws ', ' aws glue ', ' azure ', ' azure data factory ',
    ' basecamp', ' bash', ' beats ', ' big query ', ' bigquery ', ' birst', ' bitbucket',
    ' blendo ', ' bootstrap ', ' business objects bi ', ' c# ', ' c++ ', ' caffe ', ' cassandra ',
    ' cdata sync', ' chronograf ', ' ci/cd ', ' cicd ', ' clickhouse ', ' cloudera ', ' cluvio ',
    ' cntk ', ' cognos', ' composer ', ' computer vision ', ' conda', ' confluence ',
    ' couchbase ', ' css ', ' d3.js ', ' dash ', ' dashboard ', ' data factory ', ' data fusion ',
    ' data mining ', ' data studio ', ' data warehouse ', ' databricks ', ' dataddo ',
    ' dataflow ', ' datahub', ' dataiku ', ' datastage ', ' dbconvert ', ' dbeaver ', ' dbt ',
    ' deep learning ', ' dl/ml', ' docker ', 'domo ', ' dune ', ' dv360 ', ' dynamodb ',
    ' elasticsearch ', ' elt ', ' erwin ', ' etl ', ' etleap', ' excel ', 'facebook business manager ',
    ' fivetran ', ' fuzzy ', ' ga360 ', ' gcp ', ' gensim ', ' ggplot ', ' git ', ' github ', ' gitlab ',
    ' google ads ', ' google analytics ', ' google cloud platform ', ' google data flow ',
    ' google optimize ', ' google sheets ', ' google tag manager ', ' google workspace ',
    ' grafana ', ' hadoop', ' hana ', ' hanagrafana ', 'hbase ', ' hdfs ', ' hevo data ', ' hightouch ',
    ' hive ', ' hivedatabricks ', ' html ', ' hubspot ', ' ibm coremetrics ', ' inetsoft ',
    ' influxdb ', 'informatica ', ' integrate.io ', ' iri voracity ', ' izenda ', ' java ',
    ' java script ', 'javascript', 'jenkins', 'jira', ' jmp ', ' julia ', 'jupyter',
    ' k2view ', ' kafka ', ' kantar ', ' kapacitor ', ' keras ', ' kibana ', ' kubernetes ',
    ' lambda ', ' linux ', ' logstash ', ' looker ', ' lstm ', ' luidgi ', ' matillion ', ' matlab ',
    ' matplotlib ', ' mendix ', ' metabase ', ' microsoft sql ', ' microsoft sql server ',
    ' microstrategy ', ' miro ', ' mixpanel ', ' ml ', ' ml flow ', ' mlflow ', ' mongodb ', ' mxnet ',
    ' mysql ', ' natural nanguage processing ', ' neo4j ', ' nlp ', ' nltk ', ' nosql ', ' numpy ',
    ' oauth ', 'octave', ' omniture ', ' omnituregitlab ', ' openshift ', ' openstack ',
    ' optimizely ', ' oracle ', '  oracle business intelligence ', ' oracle data integrator ',
    ' pandas ', ' panorama ', ' pentaho ', ' plotly ', ' postgre ', ' postgresql ', ' posthog ',
    ' power amc ', ' power bi ', 'power point', 'powerbi', 'powerpivot', ' powerpoint ',
    ' powerquery ', ' pyspark ', 'python ', 'pytorch', 'pytorchhevo data', ' qlik ',
    ' qlik sense ', ' qliksense ', ' qlikview ',' qlikview ', ' querysurge ', ' r ', ' raphtory ', ' rapidminer ', ' redash ',
    ' redis ', 'redshift ', 'retool', 'rivery', 'rust', 's3', 'sa360', 'salesforce', ' sap ',
    ' sap business objects ', ' sas ', ' sas visual analytics ', ' scala ', ' scikit-learn ',
    ' scipy ', ' seaborn ', ' segment ', ' selenium ', ' sem rush ', ' semrush ', ' shell ', ' shiny ',
    ' singer ', ' sisense ', ' skyvia ', ' snowflake ', ' spacy ', ' spark ', ' sparkml ', ' splunk ',
    ' spotfire ', ' spreadsheet ', ' spss ', ' sql ', ' ssis ', ' sssr ', ' stambia ', ' statistics ',
    ' statsbot ', ' stitch ', ' streamlit ', ' streamsets ', ' svn ', ' t-sql ', ' tableau ', ' talend ',
    ' targit ', ' tealium ', ' telegraf ', ' tensorflow ', 'terraapi ', 'terraform ', 'theano ',
    ' thoughtspot ', ' timeseries', 'trello ', ' unix ', ' vba ', '  vtom ', ' webfocus ', ' wfh ',
    ' xplenty ', ' xtract.io ', ' yellowfin ', ' английский язык ', ' english language ', ' french language ',
    ' французский язык ', ' немецкий язык ', ' german language '
]

# %%
# создадим функцию для вычленения хард-скиллов из столбца job_description
def skill_func(cell):
    skill_list = []
    for i in skills:
        if i in cell:
            skill_list.append(i)
    return skill_list

# %%
# выполним функцию для вычленения хард скиллов из столбца job_description 
# и создадим новый столбец из этих скиллов

df_new['job_skills_des'] = df_new['job_description'].apply(skill_func)

# %%
# создадим фунекцию для вычленения хард-скиллов из столбца skills

skill_list1 = []
for i in df_new['skills']:
    skill_list1.append(i.split(':')[-1].strip().split(',')[:2])

# %%
# создадим новый столбец с хард-скиллами из столбва skills

df_new['skills_1'] = skill_list1
df_new['skills_1']
# Out:
# 0                                           [none]
# 1                                           [none]
# 2                                           [none]
# 3                                           [none]
# 4                                           [none]
#                           ...
# 802    [marketing campaigns,  marketing reporting]
# 803                       [python,  решение задач]
# 804         [data analytics,  визуализация данных]
# 805         [аналитические навыки,  немецкий язык]
# 806                                         [none]
# Name: skills_1, Length: 807, dtype: object

# %%
# объединим вычлененные хард скиллы

df_new["job_skills"] = df_new["job_skills_des"] + df_new["skills_1"]

# %%
# проверим, что хард скиллы вычленены из столбцов job_description и job_skills 
# и информация по ним объединена в столбце job_skills

df_new[['job_skills_des','skills_1','job_skills']].head(5)
# Out:
#                                       job_skills_des skills_1  \
# 0        [ data mining ,  sap ,  sas ,  statistics ]   [none]
# 1                                                 []   [none]
# 2                                                 []   [none]
# 3                                          [ excel ]   [none]
# 4  [ data warehouse ,  etl ,  oracle , python ,  ...   [none]
#
#                                           job_skills
# 0  [ data mining ,  sap ,  sas ,  statistics , none]
# 1                                             [none]
# 2                                             [none]
# 3                                    [ excel , none]
# 4  [ data warehouse ,  etl ,  oracle , python ,  ...

# %%
# с помощью функции explode разобьем списки хард скиллов на отдельные хард скиллы для корректного анализа

df_new_explode = df_new.explode("job_skills")

# %%
# посмотрим на количеству уникальных вакансий 

df_new_explode['number_vacancy'].nunique()
# Out:
# 807

# %%
# удалим столбцы со списками job_skills_des и job_skills_skil

# %%
del df_new_explode['job_skills_des']

# %%
del df_new_explode['skills_1']

# %%
# удалим строчки, в которых в столбце job_skills есть none
df_new_explode = df_new_explode.query('job_skills != "none"')

# %%
# удалим лишние проблемы
df_new_explode['job_skills'] = df_new_explode['job_skills'].str.strip()

# %%
#хард скиллы с похожими названиями и сутью объединим

replace_name(df_new_explode,'job_skills','ab testing','a/b testing')
replace_name(df_new_explode,'job_skills','java script','javascript')
replace_name(df_new_explode,'job_skills','pandas','python')
replace_name(df_new_explode,'job_skills','matplotlib','python')
replace_name(df_new_explode,'job_skills','seaborn','python')
replace_name(df_new_explode,'job_skills','numpy','python')
replace_name(df_new_explode,'job_skills','scipy','python')
replace_name(df_new_explode,'job_skills','plotly','python')
replace_name(df_new_explode,'job_skills','cicd','ci/cd')
replace_name(df_new_explode,'job_skills','postgre','sql')
replace_name(df_new_explode,'job_skills','postgresql','sql')
replace_name(df_new_explode,'job_skills','powerbi','power bi')
replace_name(df_new_explode,'job_skills','qlik sense','qlik')
replace_name(df_new_explode,'job_skills','qliksense','qlik')
replace_name(df_new_explode,'job_skills','qlikview','qlik')
replace_name(df_new_explode,'job_skills','qlik view','qlik')
replace_name(df_new_explode,'job_skills','big query','bigquery')
replace_name(df_new_explode,'job_skills','mysql','sql')
replace_name(df_new_explode,'job_skills','nosql','sql')
replace_name(df_new_explode,'job_skills','microsoft sql','microsoft sql server')
replace_name(df_new_explode,'job_skills','ml flow','mlflow')
replace_name(df_new_explode,'job_skills','aws glue','aws')
replace_name(df_new_explode,'job_skills','etl tools','etl')
replace_name(df_new_explode,'job_skills','a/b тестирование','a/b testing')
replace_name(df_new_explode,'job_skills','microsoft sql server server','microsoft sql server')
replace_name(df_new_explode,'job_skills','microsoft sql server server','microsoft sql server server')
replace_name(df_new_explode,'job_skills','microsoft sql server server server server','microsoft sql server')
replace_name(df_new_explode,'job_skills','microsoft sql server server server server server','microsoft sql server')
replace_name(df_new_explode,'job_skills','msql','sql')
replace_name(df_new_explode,'job_skills','powerpoint','power point')
replace_name(df_new_explode,'job_skills','sqlsql','sql')
replace_name(df_new_explode,'job_skills',' statutory accounting principles (sap) ','sap')
replace_name(df_new_explode,'job_skills','искусственный интеллект<!-- --></span>','ai')
replace_name(df_new_explode,'job_skills','visualization','визуализация данных')
replace_name(df_new_explode,'job_skills','microsoft excel','excel')
replace_name(df_new_explode,'job_skills','salesforce.com','salesforce')
replace_name(df_new_explode,'job_skills','english language','английский язык')
replace_name(df_new_explode,'job_skills','статистика','statistics')
replace_name(df_new_explode,'job_skills','машинное обучение','machine learning')
replace_name(df_new_explode,'job_skills','ml','machine learning')
replace_name(df_new_explode,'job_skills','machine learning algorithms','machine learning')
replace_name(df_new_explode,'job_skills','yellowfin','yellowfin bi')
replace_name(df_new_explode,'job_skills','yellowfin bi bi','yellowfin bi')
replace_name(df_new_explode,'job_skills','statistics по компании','statistics')
replace_name(df_new_explode,'job_skills','snowflake cloud','snowflake')
replace_name(df_new_explode,'job_skills','google bigquery','bigquery')
#replace_name(df_new_explode,'job_skills',' google cloud platform ','google cloud platform (gcp)')

# %%
# проверим таблицу на наличие дубликатов
df_new_explode.duplicated().sum()
# Out:
# 197

# %%
# удалим явные дублированные строки и проверим, что их не осталось
df_new_explode = df_new_explode.drop_duplicates()

# %%
# проверим, что все дубликаты удалены
df_new_explode.duplicated().sum()
# Out:
# 0

# %%
sorted(df_new_explode['job_skills'].unique())
# Out:
# ['a/b testing',
#  'abstracting',
#  'ad hoc analysis',
#  'adobe analytics',
#  'adobe target',
#  'agile software development',
#  'ai',
#  'airflow',
#  'algorithm development',
#  'alteryx',
#  'amachine learning',
#  'amazon elastic mapreduce (emr)',
#  'amazon kinesis',
#  'amazon quicksight',
#  'amazon web services (aws)',
#  'amplitude',
#  'analytical modelling',
#  'analytique',
#  'apache kafka',
#  'apache spark',
#  'apache spark streaming',
#  'api',
#  'application services',
#  'attention to detail',
#  'attribution',
#  'aws',
#  'azure',
#  'bash',
#  'basque',
#  'bigquery',
#  'bitbucket',
#  'bpmn',
#  'budget tracking',
#  'business administration',
#  'business analysis',
#  'business case development',
#  'business case preparation',
#  'business reviews',
#  'business solution',
#  'business support',
#  'c#',
#  'c++',
#  'ci/cd',
#  'clickhouse',
#  'cloudera',
#  'cluster analysis',
#  'cognos',
#  'commerce',
#  'confluence',
#  'coordinating skills',
#  'crm',
#  'cross-channel marketing',
#  'cross-team collaboration',
#  'css',
#  'cultural affairs',
#  'dash',
#  'dashboard',
#  'data analytics',
#  'data engineering',
#  'data feeds',
#  'data governance',
#  'data interpretation',
#  'data manipulation',
#  'data mining',
#  'data pipelines',
#  'data studio',
#  'data warehouse',
#  'data-driven decision making',
#  'database queries',
#  'databricks',
#  'dataiku dss',
#  'datastage',
#  'dax',
#  'dbt',
#  'dcf valuation',
#  'deep learning',
#  'dhcp',
#  'digital technology',
#  'docker',
#  'domo',
#  'ecmascript',
#  'elt',
#  'enterprise service bus (esb) architecture',
#  'environmental',
#  'erd',
#  'esprit',
#  'etl',
#  'excel',
#  'factiva',
#  'feature extraction',
#  'fivetran',
#  'french language',
#  'futures',
#  'gcp',
#  'german language',
#  'git',
#  'github',
#  'gitlab',
#  'gmp (надлежащая производственная практика)',
#  'google analytics',
#  'google cloud platform',
#  'google cloud platform (gcp)',
#  'google data studio',
#  'google sheets',
#  'google tag manager',
#  'google workspace',
#  'hadoop',
#  'hana',
#  'high level of accuracy',
#  'htmachine learning',
#  'hubspot',
#  'human behavior',
#  'hyperion financial management (hfm)',
#  'hypothesis testing',
#  'industrial internet of things (iiot)',
#  'informatica',
#  'interpreting data',
#  'it business analysis',
#  'it solutions',
#  'itil',
#  'java',
#  'javascript',
#  'jenkins',
#  'jira',
#  'julia',
#  'jupyter',
#  'kafka',
#  'keras',
#  'kibana',
#  'kubernetes',
#  'lambda',
#  'learning',
#  'linux',
#  'looker',
#  'looker (software)',
#  'machine learning',
#  'marketing campaigns',
#  'marketing mix modeling',
#  'marketing reporting',
#  'matillion',
#  'matlab',
#  'metabase',
#  'metrics definition',
#  'microsoft dynamics nav',
#  'microsoft office',
#  'microsoft power bi',
#  'microsoft power query',
#  'microsoft sql server',
#  'microstrategy',
#  'mixpanel',
#  'mobile switching centre server (mss)',
#  'moe',
#  'mongodb',
#  'new product rollout',
#  'nlp',
#  'oracle',
#  'oracle data integrator (odi)',
#  'oral communication',
#  'outlook',
#  'panorama',
#  'payroll administration',
#  'personal data',
#  'photoshop',
#  'php',
#  'pl/sql',
#  'power bi',
#  'power point',
#  'powerpivot',
#  'powerquery',
#  'priority management',
#  'product control',
#  'product service',
#  'project+',
#  'pyspark',
#  'python',
#  'python (software)',
#  'pytorch',
#  'qlik',
#  'quantitative data',
#  'query languages',
#  'quotations',
#  'r',
#  'rapidminer',
#  'recovery plans',
#  'redshift',
#  'requirements engineering',
#  'rstudio',
#  'rust',
#  's3',
#  'salesforce',
#  'salesforce sales cloud',
#  'sap',
#  'sap bw',
#  'sap erp',
#  'sap srm',
#  'sas',
#  'scala',
#  'segment',
#  'sharepoint',
#  'shell',
#  'shiny',
#  'sisense',
#  'snowflake',
#  'social',
#  'spark',
#  'spotfire',
#  'spreadsheet',
#  'spring cloud',
#  'spss',
#  'spss clementine',
#  'sql',
#  'ssis',
#  'ssrs',
#  'statistical analysis',
#  'statistics',
#  'statutory accounting principles (sap)',
#  'tableau',
#  'talend',
#  'targit',
#  'technical solution design',
#  'tensorflow',
#  'timeseries',
#  'umachine learning',
#  'unix',
#  'vba',
#  'vbscript',
#  'web concepts',
#  'yellowfin bi',
#  'автоматизация тестирования',
#  'администрирование salesforce',
#  'анализ бизнес-данных',
#  'анализ данных',
#  'анализ требований',
#  'аналитика',
#  'аналитические навыки',
#  'английский язык',
#  'базы данных',
#  'бизнес-аналитика',
#  'бизнес-объекты',
#  'бизнес-приложения',
#  'бизнес-процессы',
#  'бизнес-требования',
#  'большие массивы данных',
#  'бухгалтерский учёт',
#  'веб-сервисы',
#  'веб-технологии',
#  'ведение переговоров',
#  'визуализация данных',
#  'витрины данных',
#  'гибкая методология программирования',
#  'данные о клиентах',
#  'документация',
#  'еда и напитки',
#  'законодательные отношения',
#  'инвестиционно-банковская деятельность',
#  'инженерное дело',
#  'интеллектуальный анализ данных',
#  'интернет-исследование',
#  'информационные технологии',
#  'истории пользователей',
#  'каталог',
#  'качество данных',
#  'ключевые показатели деятельности',
#  'командная работа',
#  'коммуникабельность',
#  'коммуникация',
#  'компьютерная наука',
#  'контроль качества',
#  'координация',
#  'корпоративные финансы',
#  'критическое мышление',
#  'лабораторные навыки',
#  'маркетинговые исследования',
#  'математика',
#  'международная логистика',
#  'межличностное общение',
#  'межсетевая защита',
#  'модели данных',
#  'моделирование данных',
#  'моторы',
#  'мсфо',
#  'наборы данных',
#  'навыки презентаций',
#  'написание запросов',
#  'написание политики',
#  'наука о данных',
#  'научно-исследовательская деятельность',
#  'недвижимость',
#  'немецкий язык',
#  'нидерландский язык',
#  'облачные вычисления',
#  'обмен электронными данными',
#  'обработка естественного языка',
#  'операционная деятельность',
#  'организаторские навыки',
#  'организация информационных хранилищ',
#  'основные данные',
#  'основные показатели',
#  'отчетность',
#  'панель управления',
#  'письменное сообщение',
#  'план счетов',
#  'планирование возможностей',
#  'планирование потребности в материалах',
#  'планы проекта',
#  'помощь исполнительному директору по административным вопросам',
#  'помощь по административным вопросам<!-- --></span>',
#  'построение карты бизнес-процессов',
#  'построение отношений',
#  'предоставление данных',
#  'презентации',
#  'приемочное испытание',
#  'прикладная математика',
#  'принятие решений',
#  'прогнозирование',
#  'прогнозное моделирование',
#  'проектирование баз данных',
#  'проектирование пользовательского интерфейса (ued)',
#  'профессиональные навыки работы с компьютером',
#  'профилактическое техническое обслуживание',
#  'пфи',
#  'работа поставщиков',
#  'работа с ключевыми клиентами',
#  'разработка систем',
#  'рассмотрение заявок',
#  'решение задач',
#  'решение проблем',
#  'розничная торговля',
#  'розничная торговля через интернет',
#  'сбор данных',
#  'сбор требований',
#  'сводные таблицы',
#  'сегментация рынка',
#  'сетевая безопасность',
#  'скрам',
#  'служба поддержки',
#  'соглашения об уровне услуг',
#  'сотрудничество',
#  'сохраненные процедуры',
#  'социальные медиа',
#  'социальные навыки',
#  'спецификация требований',
#  'средства бизнес-аналитики',
#  'статистическое моделирование',
#  'стратегии ценообразования',
#  'стратегия',
#  'стратегия ведения бизнеса',
#  'творческий подход к решению проблем',
#  'тестирование на приемлемость для пользователя',
#  'техническая поддержка',
#  'технологическая подготовка производства',
#  'транспортировка по трубопроводу',
#  'управление взаимодействием с корпоративными клиентами',
#  'управление вознаграждением работников',
#  'управление данными',
#  'управление логистикой',
#  'управление материалами',
#  'управление объемом работ',
#  'управление операциями',
#  'управление отношениями с заинтересованными сторонами',
#  'управление предприятием',
#  'управление проектами',
#  'урегулирование споров',
#  'услуги анализа',
#  'финансовая математика',
#  'финансовые услуги',
#  'финансовый анализ',
#  'финансы',
#  'французский язык',
#  'функциональные требования',
#  'целевая цена',
#  'цифровой маркетинг',
#  'экологическая сбалансированность',
#  'экономика',
#  'языки программирования']

# %%
# найдем хард скиллы, которые встречаются 1-3 раза на весь датасет

df_new_explode_bottom = (df_new_explode.groupby(['job_skills']).agg({'number_vacancy':'count'}).sort_values(by='number_vacancy'\
                                                                    ,ascending=True).reset_index())
df_new_explode_bottom1 = df_new_explode_bottom[df_new_explode_bottom['number_vacancy'].isin([1,2,3])]

df_new_explode_bottom1_skills = df_new_explode_bottom1['job_skills']

# удалим хард скиллы, которые встречается 1-3 раза на весь датасет

df_new_explode_top = df_new_explode.query('job_skills not in @df_new_explode_bottom1_skills')

# %%
print('Количество хард-скиллов всего - {a}, количество хард-скиллов, которые встречаются 1-3 раза {b} ({c:.2%})'.\
     format(a=df_new_explode['job_skills'].count(),b=df_new_explode_bottom1_skills.count(),c=df_new_explode_bottom1_skills\
            .count()/df_new_explode['job_skills'].count()))
# Out:
# Количество хард-скиллов всего - 3055, количество хард-скиллов, которые встречаются 1-3 раза 277 (9.07%)

# %%
df_new_explode_bottom1_skills.tolist()
# Out:
# ['языки программирования',
#  'recovery plans',
#  'redshift',
#  'технологическая подготовка производства',
#  'salesforce sales cloud',
#  'техническая поддержка',
#  'sap bw',
#  'sap srm',
#  'shiny',
#  'sisense',
#  'тестирование на приемлемость для пользователя',
#  'social',
#  'spotfire',
#  'spring cloud',
#  'управление взаимодействием с корпоративными клиентами',
#  'творческий подход к решению проблем',
#  'стратегия ведения бизнеса',
#  'ssrs',
#  'statistical analysis',
#  'стратегия',
#  'statutory accounting principles (sap)',
#  'стратегии ценообразования',
#  'targit',
#  'technical solution design',
#  'tensorflow',
#  'timeseries',
#  'umachine learning',
#  'vbscript',
#  'web concepts',
#  'spss clementine',
#  'quotations',
#  'quantitative data',
#  'python (software)',
#  'marketing campaigns',
#  'marketing mix modeling',
#  'marketing reporting',
#  'matillion',
#  'metabase',
#  'metrics definition',
#  'microsoft dynamics nav',
#  'управление объемом работ',
#  'mixpanel',
#  'mobile switching centre server (mss)',
#  'moe',
#  'mongodb',
#  'new product rollout',
#  'oracle data integrator (odi)',
#  'oral communication',
#  'outlook',
#  'panorama',
#  'payroll administration',
#  'personal data',
#  'photoshop',
#  'php',
#  'pl/sql',
#  'управление материалами',
#  'сегментация рынка',
#  'priority management',
#  'product control',
#  'product service',
#  'project+',
#  'pyspark',
#  'автоматизация тестирования',
#  'администрирование salesforce',
#  'социальные навыки',
#  'бизнес-приложения',
#  'операционная деятельность',
#  'организация информационных хранилищ',
#  'основные данные',
#  'служба поддержки',
#  'письменное сообщение',
#  'план счетов',
#  'планирование возможностей',
#  'планирование потребности в материалах',
#  'планы проекта',
#  'помощь исполнительному директору по административным вопросам',
#  'помощь по административным вопросам<!-- --></span>',
#  'построение карты бизнес-процессов',
#  'построение отношений',
#  'приемочное испытание',
#  'прикладная математика',
#  'прогнозирование',
#  'проектирование баз данных',
#  'проектирование пользовательского интерфейса (ued)',
#  'пфи',
#  'работа поставщиков',
#  'работа с ключевыми клиентами',
#  'разработка систем',
#  'рассмотрение заявок',
#  'скрам',
#  'решение проблем',
#  'розничная торговля',
#  'розничная торговля через интернет',
#  'сбор данных',
#  'сводные таблицы',
#  'обмен электронными данными',
#  'looker (software)',
#  'облачные вычисления',
#  'научно-исследовательская деятельность',
#  'бизнес-процессы',
#  'большие массивы данных',
#  'бухгалтерский учёт',
#  'веб-сервисы',
#  'веб-технологии',
#  'ведение переговоров',
#  'витрины данных',
#  'гибкая методология программирования',
#  'данные о клиентах',
#  'еда и напитки',
#  'законодательные отношения',
#  'инженерное дело',
#  'интеллектуальный анализ данных',
#  'интернет-исследование',
#  'информационные технологии',
#  'каталог',
#  'сохраненные процедуры',
#  'сотрудничество',
#  'контроль качества',
#  'координация',
#  'корпоративные финансы',
#  'лабораторные навыки',
#  'международная логистика',
#  'межсетевая защита',
#  'моторы',
#  'навыки презентаций',
#  'написание запросов',
#  'написание политики',
#  'соглашения об уровне услуг',
#  'недвижимость',
#  'learning',
#  'управление логистикой',
#  'сетевая безопасность',
#  'commerce',
#  'environmental',
#  'cluster analysis',
#  'erd',
#  'esprit',
#  'урегулирование споров',
#  'cloudera',
#  'clickhouse',
#  'c#',
#  'factiva',
#  'business support',
#  'feature extraction',
#  'fivetran',
#  'french language',
#  'futures',
#  'business solution',
#  'business case development',
#  'business administration',
#  'budget tracking',
#  'enterprise service bus (esb) architecture',
#  'bpmn',
#  'elt',
#  'coordinating skills',
#  'lambda',
#  'финансовая математика',
#  'data manipulation',
#  'data interpretation',
#  'услуги анализа',
#  'data feeds',
#  'database queries',
#  'финансовые услуги',
#  'dash',
#  'dataiku dss',
#  'datastage',
#  'dax',
#  'cultural affairs',
#  'dcf valuation',
#  'cross-team collaboration',
#  'dhcp',
#  'digital technology',
#  'cross-channel marketing',
#  'crm',
#  'ecmascript',
#  'bitbucket',
#  'финансы',
#  'gmp (надлежащая производственная практика)',
#  'hyperion financial management (hfm)',
#  'hypothesis testing',
#  'basque',
#  'analytical modelling',
#  'interpreting data',
#  'it business analysis',
#  'it solutions',
#  'itil',
#  'amazon web services (aws)',
#  'human behavior',
#  'amazon quicksight',
#  'jenkins',
#  'управление операциями',
#  'amazon elastic mapreduce (emr)',
#  'amachine learning',
#  'экологическая сбалансированность',
#  'keras',
#  'agile software development',
#  'adobe target',
#  'abstracting',
#  'amazon kinesis',
#  'hubspot',
#  'industrial internet of things (iiot)',
#  'data pipelines',
#  'attribution',
#  'htmachine learning',
#  'application services',
#  'цифровой маркетинг',
#  'apache spark streaming',
#  'apache kafka',
#  'analytique',
#  'apache spark',
#  'управление предприятием',
#  'управление отношениями с заинтересованными сторонами',
#  'hana',
#  'bash',
#  'целевая цена',
#  'финансовый анализ',
#  'бизнес-аналитика',
#  'нидерландский язык',
#  'data engineering',
#  'сбор требований',
#  'algorithm development',
#  'business case preparation',
#  'предоставление данных',
#  'наборы данных',
#  'профилактическое техническое обслуживание',
#  'профессиональные навыки работы с компьютером',
#  'мсфо',
#  'прогнозное моделирование',
#  'принятие решений',
#  'amplitude',
#  'маркетинговые исследования',
#  'критическое мышление',
#  'ci/cd',
#  'business reviews',
#  'документация',
#  'kubernetes',
#  'german language',
#  'sap erp',
#  'экономика',
#  'rstudio',
#  'requirements engineering',
#  'спецификация требований',
#  'rapidminer',
#  'github',
#  'query languages',
#  'shell',
#  'gitlab',
#  'google data studio',
#  'google sheets',
#  'powerquery',
#  'google workspace',
#  'nlp',
#  'julia',
#  'kafka',
#  'linux',
#  'управление вознаграждением работников',
#  'domo',
#  'анализ требований',
#  'data-driven decision making',
#  'средства бизнес-аналитики',
#  'yellowfin bi',
#  'confluence',
#  's3',
#  'data governance',
#  'модели данных',
#  'обработка естественного языка',
#  'google cloud platform (gcp)',
#  'функциональные требования',
#  'c++',
#  'отчетность',
#  'sharepoint',
#  'microstrategy',
#  'microsoft power query',
#  'коммуникабельность',
#  'unix',
#  'docker',
#  'css']

# %%
# удалим софт-скиллы и то, что не относится к скиллам

df_new_explode_top = df_new_explode_top.query('job_skills not in ["транспортировка по трубопроводу","управление проектами",\
"управление данными","статистика по компании","социальные медиа","решение задач","панель управления","основные показатели",\
"организаторские навыки","презентации","наука о данных","межличностное общение","коммуникация","командная работа",\
"ключевые показатели деятельности","качество данных","истории пользователей","инвестиционно-банковская деятельность",\
"бизнес-требования","бизнес-объекты","аналитические навыки","аналитика","анализ бизнес-данных","анализ данных",\
"attention to detail","business analysis","data analytics"]')

# %%
# уберем middle и senior

senior = df_new_explode_top[df_new_explode_top['title'].str.contains('senior')]['number_vacancy']
df_new_explode_top = df_new_explode_top.query('number_vacancy not in @senior')

middle = df_new_explode_top[df_new_explode_top['title'].str.contains('middle')]['number_vacancy']
df_new_explode_top = df_new_explode_top.query('number_vacancy not in @middle')

# %%
# проверим, что убрали middle и senior
df_new_explode_top[df_new_explode_top['title'].str.contains('senior') | df_new_explode_top['title'].str.contains('middle')]
# Out:
# Empty DataFrame
# Columns: [number_vacancy, title, location, country, employment_type, company_name, employee_qty, company_field, skills, job_description, applicants, job_skills]
# Index: []

# %% [markdown]
# **Разобьем все вакансии на продуктовых аналитиков, маркетинговых аналитиков, бизнес-аналитиков, финансовых аналитиков и дата сайнтистов**

# %%
# создание функции

def name_vacancy (row):
    
    #for i in row['title']
    if 'product' in row['title']:
        return 'product analyst'
    elif 'marketing' in row['title']:
        return 'marketing analyst'
    elif 'business' in row['title']:
        return 'business analyst'
    elif 'financ' in row['title']:
        return 'finance analyst'
    elif 'scientist' in row['title']:
        return 'data scientist'
    elif 'bi ' in row['title']:
        return 'bi analyst'
    else:
        return 'data analyst'
    
# создание нового столбца с разбивкой по типам аналитиков   
    
df_new_explode_top['name_vacancy'] = df_new_explode_top.apply(name_vacancy,axis=1)

# %%
# проверка
df_new_explode_top.groupby('name_vacancy')['number_vacancy'].nunique().sort_values(ascending=False)
# Out:
# name_vacancy
# data analyst         538
# business analyst      75
# data scientist        39
# product analyst       19
# marketing analyst     17
# finance analyst       14
# bi analyst            11
# Name: number_vacancy, dtype: int64

# %% [markdown]
# ## Перевод полученной таблицы в формат Excel

# %%
df_linkedln1 = df_new_explode_top.to_excel('D:\df_linkedln1.xlsx')
